# %%
import pandas as pd 
import numpy as np
import time
from sklearn.model_selection import RandomizedSearchCV
import xgboost as xgb
from sklearn.preprocessing import StandardScaler
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier

# %%
path = 'training.csv' # path to the file we're looking at. 
# in this case the file is in the same folder as my notebook, so I don't need to specify the full path
train_df = pd.read_csv(path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [2], in <module>
#       1 path = 'training.csv' # path to the file we're looking at.
#       2 # in this case the file is in the same folder as my notebook, so I don't need to specify the full path
# ----> 3 train_df = pd.read_csv(path)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\parsers\readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\parsers\readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\parsers\readers.py:933, in TextFileReader.__init__(self, f, engine, **kwds)
#     930     self.options["has_index_names"] = kwds["has_index_names"]
#     932 self.handles: IOHandles | None = None
# --> 933 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\parsers\readers.py:1217, in TextFileReader._make_engine(self, f, engine)
#    1213     mode = "rb"
#    1214 # error: No overload variant of "get_handle" matches argument types
#    1215 # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1216 # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1217 self.handles = get_handle(  # type: ignore[call-overload]
#    1218     f,
#    1219     mode,
#    1220     encoding=self.options.get("encoding", None),
#    1221     compression=self.options.get("compression", None),
#    1222     memory_map=self.options.get("memory_map", False),
#    1223     is_text=is_text,
#    1224     errors=self.options.get("encoding_errors", "strict"),
#    1225     storage_options=self.options.get("storage_options", None),
#    1226 )
#    1227 assert self.handles is not None
#    1228 f = self.handles.handle
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\common.py:789, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784 elif isinstance(handle, str):
#     785     # Check whether the filename is to be opened in binary mode.
#     786     # Binary mode does not support 'encoding' and 'newline'.
#     787     if ioargs.encoding and "b" not in ioargs.mode:
#     788         # Encoding
# --> 789         handle = open(
#     790             handle,
#     791             ioargs.mode,
#     792             encoding=ioargs.encoding,
#     793             errors=errors,
#     794             newline="",
#     795         )
#     796     else:
#     797         # Binary mode
#     798         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'training.csv'

# %%
path = 'test.csv'
test_df = pd.read_csv(path)

# %%
# very basic preprocessing...let's just keep the columns we want to keep!

# %%
# want to keep info about the patient themselves also some specifc regional data that could have an impact on the patient's health
# i'm excluded the demographic info that's not a characteristic of the patients themselves
cols = [
    'patient_race',
    'payer_type',
    'patient_state',
    'patient_age',
    'patient_gender',
    'breast_cancer_diagnosis_code',
    'metastatic_cancer_diagnosis_code',
    'patient_zip3'
]
# NOTE - IF USING PATIENT_ZIP3, TREAT IT LIKE A CATEGORICAL VARIABLE

train_df_simple = train_df[cols]
test_df_simple = test_df[cols]

# %%
# simple preprocessing

# %%
# fill in nulls
categorical_cols = train_df_simple.select_dtypes(include=['object']).columns.to_list() + ['patient_zip3']
numerical_cols = train_df_simple.select_dtypes(exclude=['object']).columns.to_list()

print('CATEGORICAL: ', categorical_cols)
print('NUMERICAL: ', numerical_cols)

# median for numerical - zip3 is categorical so fill it in with 0 for now
for c in numerical_cols :
    if c == 'patient_zip3':
        train_df_simple[c].fillna(value=0, inplace=True)
        continue
    train_df_simple[c].fillna(value=train_df_simple[c].median(), inplace=True)
    test_df_simple[c].fillna(value=test_df_simple[c].median(), inplace=True)
    
# 'None' for categorical (the rest)
train_df_simple.replace(np.nan, 'None', regex=True,inplace=True)
test_df_simple.replace(np.nan, 'None', regex=True,inplace=True)
# Out:
# CATEGORICAL:  ['patient_race', 'payer_type', 'patient_state', 'patient_gender', 'breast_cancer_diagnosis_code', 'metastatic_cancer_diagnosis_code', 'patient_zip3']
# NUMERICAL:  ['patient_age', 'patient_zip3']
# C:\Users\parth\AppData\Local\Temp\ipykernel_13088\3511704863.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df_simple[c].fillna(value=train_df_simple[c].median(), inplace=True)
# C:\Users\parth\AppData\Local\Temp\ipykernel_13088\3511704863.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df_simple[c].fillna(value=test_df_simple[c].median(), inplace=True)
# C:\Users\parth\AppData\Local\Temp\ipykernel_13088\3511704863.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df_simple[c].fillna(value=0, inplace=True)
# C:\Users\parth\AppData\Local\Temp\ipykernel_13088\3511704863.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df_simple.replace(np.nan, 'None', regex=True,inplace=True)
# C:\Users\parth\AppData\Local\Temp\ipykernel_13088\3511704863.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df_simple.replace(np.nan, 'None', regex=True,inplace=True)

# %%
# encode categorical variables
train_df_simple = pd.get_dummies(train_df_simple, columns=categorical_cols)  
test_df_simple = pd.get_dummies(test_df_simple, columns=categorical_cols) 

print(train_df_simple.shape)
print(test_df_simple.shape)
# Out:
# (12906, 895)
# (5792, 820)

# %%
# get list of missing cols in test data 
missing_cols = [x for x in train_df_simple.columns if x not in test_df_simple.columns and x != 'DiagPeriodL90D']

# add these cols with default value = 0
for c in missing_cols:
    test_df_simple[c] = 0
    
# reorder the columns to make sure the test and train are the same
test_df_simple = test_df_simple[train_df_simple.columns]

print(train_df_simple.shape)
print(test_df_simple.shape)
# Out:
# (12906, 895)
# (5792, 895)
# C:\Users\parth\AppData\Local\Temp\ipykernel_13088\322192473.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   test_df_simple[c] = 0
# C:\Users\parth\AppData\Local\Temp\ipykernel_13088\322192473.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   test_df_simple[c] = 0
# C:\Users\parth\AppData\Local\Temp\ipykernel_13088\322192473.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   test_df_simple[c] = 0
# C:\Users\parth\AppData\Local\Temp\ipykernel_13088\322192473.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   test_df_simple[c] = 0
# C:\Users\parth\AppData\Local\Temp\ipykernel_13088\322192473.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   test_df_simple[c] = 0
# C:\Users\parth\AppData\Local\Temp\ipykernel_13088\322192473.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   test_df_simple[c] = 0
# C:\Users\parth\AppData\Local\Temp\ipykernel_13088\322192473.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   test_df_simple[c] = 0
# C:\Users\parth\AppData\Local\Temp\ipykernel_13088\322192473.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   test_df_simple[c] = 0

# %%
# standardize the data
scaler = StandardScaler()
X_train = scaler.fit_transform(train_df_simple)
X_test = scaler.transform(test_df_simple)

# %%
# train models
iteration = 0
y_train = train_df['DiagPeriodL90D']

# %%
# hard code params

# %%
iteration2 = 0

# %%
param_grid = {
    
    'depth':2,
    'random_state': 42,
    'eval_metric': 'AUC',
    'verbose': False,
    'loss_function': 'Logloss',
    'learning_rate':0.3,
    'iterations':1000
}

model = CatBoostClassifier(**param_grid)
model.fit(X_train, y_train)

# get the probabilities using the test data
probabilities = model.predict_proba(X_test)

print (probabilities)

# create df for submission
sub_df = test_df[['patient_id']]
sub_df['DiagPeriodL90D'] = probabilities[:,1]

# save the submission
display(sub_df)

sub_df.to_csv('simplified_submission_cb_' + str(iteration2) + '.csv', index=False)

# %%
# cross validation and parameter tuning example - catboost
from sklearn.model_selection import GridSearchCV
start_time = time.time() # start timer


# param_grid = {'random_strength': 0.1, 'learning_rate': 0.05, 'l2_leaf_reg': 5, 
#               'iterations': 150, 'depth': 8, 'border_count': 100, 'bagging_temperature': 0.2,
#                'eval_metric':'AUC',
#              }
# random_search = CatBoostClassifier(**param_grid)


model = CatBoostClassifier(silent=True)

# Define hyperparameters - this will depend on the model. you can refer to the docs or use ChatGPT to spit out different parameter tests
# these are arbitrary values I got from ChatGPT
param_grid = {
    'iterations': [[50, 100, 150, 200],
    'learning_rate': [0.05, 0.1], # [0.01, 0.05, 0.1],
    'depth': [4, 6, 8 ],
    'l2_leaf_reg': [5], # [1, 5, 10],
    'border_count': [100], # [5, 10, 20, 50, 100],
    'random_strength': [0.1, 0.5], # [0.1, 0.5 1.0],
    'bagging_temperature': [0.2, 0.5, 0.8],
    'eval_metric' : ['AUC'],
}


# Use RandomizedSearchCV/GridSearchCV to search for the best hyperparameters - will use n_iter random combinations of  parameters
random_search = RandomizedSearchCV(estimator=model, param_distributions=param_grid,
                                   scoring='accuracy' , n_iter=20, cv=3, random_state=26)

# random_search = GridSearchCV(estimator=model, param_grid=param_grid,
#                              scoring='accuracy', cv=3)



random_search.fit(X_train, y_train)

end_time = time.time() # end the timer
elapsed_time_seconds = end_time - start_time

# print the elapsed time
print(f"\nElapsed Time: {int(elapsed_time_seconds // 60)} minutes and {elapsed_time_seconds % 60} seconds")

# Print the best parameters and corresponding accuracy
print("\nBest Parameters: ", random_search.best_params_)
print("\nBest Accuracy: {:.2f}".format(random_search.best_score_))

iteration2 += 1
# Out:
# Elapsed Time: 6 minutes and 35.19725847244263 seconds
#
# Best Parameters:  {'random_strength': 0.5, 'learning_rate': 0.05, 'l2_leaf_reg': 5, 'iterations': 500, 'eval_metric': 'AUC', 'depth': 4, 'border_count': 100, 'bagging_temperature': 0.8}
#
# Best Accuracy: 0.81

# %%
# create the cb model using the winning parameters
best_model = random_search.best_estimator_
best_model.fit(X_train, y_train)

# get the probabilities using the test data
probabilities = random_search.predict_proba(X_test)

print (probabilities)

# create df for submission
sub_df = test_df[['patient_id']]
sub_df['DiagPeriodL90D'] = probabilities[:,1]

# save the submission
display(sub_df)

sub_df.to_csv('simplified_submission_cb_' + str(iteration2) + '.csv', index=False)
# Out:
# [[0.22423922 0.77576078]
#  [0.32555508 0.67444492]
#  [0.21687659 0.78312341]
#  ...
#  [0.10462079 0.89537921]
#  [0.90161647 0.09838353]
#  [0.1377912  0.8622088 ]]
# C:\Users\parth\AppData\Local\Temp\ipykernel_13088\1747049896.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df['DiagPeriodL90D'] = probabilities[:,1]
#       patient_id  DiagPeriodL90D
# 0         573710        0.775761
# 1         593679        0.674445
# 2         184532        0.783123
# 3         447383        0.776386
# 4         687972        0.799344
# ...          ...             ...
# 5787      977076        0.843012
# 5788      922960        0.863509
# 5789      759690        0.895379
# 5790      911717        0.098384
# 5791      327597        0.862209
#
# [5792 rows x 2 columns]

# %%
# LOGGING 2/23/24 -- NOTE THAT ANY SUBMISSIONS NAMED _LBGM WERE ACTUALLY CATBOOST
# test 0 - random_state = 52, n_iter = 10
# test 1 - random_state = 26, n_iter = 15 --> WINNER 0.805
# Best Parameters:  {'random_strength': 0.1, 'learning_rate': 0.05, 'l2_leaf_reg': 5, 'iterations': 150, 'depth': 8, 'border_count': 100, 'bagging_temperature': 0.2}
# test 2 - random_state = None, n_iter = 15
# test 3 - random_state = None, n_ter = 20 --> 0.804 (with the current set of params) 
# test 4 --> replaced randomsearch with gridsearch and specified more params. hit a stopping point. try something new?


# LOGGING 2/25/24 
# test 5 - random_state  = 26, n_iter = 20, eval_metric = 'logloss'
# test 6 - using the winning parameters from yesterday but doing eval_metric = AUC --> GAVE 0.805 AGAIN.
# {'random_strength': 0.1, 'learning_rate': 0.05, 'l2_leaf_reg': 5, 'iterations': 150, 'depth': 8, 'border_count': 100, 'bagging_temperature': 0.2}

# LOGGING 2/25/24 (REFRESHED THE NOTEBOOK - added patient_zip3 back to list of cols)
# test - random_state = 26, n_iter = 20 
# TODO - CHANGED SOME PREPROCESSING. TEST ON XGBOOST NOTEBOOK

# %%
# iteration3 = 0

# %%
# # cross validation and parameter tuning example - lgbm
# from sklearn.model_selection import GridSearchCV
# start_time = time.time() # start timer

# model = LGBMClassifier()

# # Define hyperparameters - this will depend on the model. you can refer to the docs or use ChatGPT to spit out different parameter tests
# # these are arbitrary values I got from ChatGPT
# param_grid = {
#     'boosting_type': ['gbdt', 'dart', 'goss'],
#     'num_leaves': [10, 20, 30, 40, 50],
#     'learning_rate': [0.01, 0.05, 0.1, 0.2],
#     'n_estimators': [50, 100, 150, 200],
#     'max_depth': [-1, 5, 10, 15, 20],
#     'min_child_samples': [5, 10, 15],
#     'subsample': [0.8, 0.9, 1.0],
#     'colsample_bytree': [0.8, 0.9, 1.0],
# }

# # Use RandomizedSearchCV/GridSearchCV to search for the best hyperparameters - will use n_iter random combinations of  parameters
# random_search = RandomizedSearchCV(estimator=model, param_distributions=param_grid,
#                                    scoring='accuracy', n_iter=15, cv=3, random_state=52)

# # random_search = GridSearchCV(estimator=model, param_grid=param_grid,
# #                              scoring='accuracy', cv=3)

# random_search.fit(X_train, y_train)

# end_time = time.time() # end the timer
# elapsed_time_seconds = end_time - start_time

# # print the elapsed time
# print(f"\nElapsed Time: {int(elapsed_time_seconds // 60)} minutes and {elapsed_time_seconds % 60} seconds")

# # Print the best parameters and corresponding accuracy
# print("\nBest Parameters: ", random_search.best_params_)
# print("\nBest Accuracy: {:.2f}".format(random_search.best_score_))

# iteration3 += 1
# Out:
# [LightGBM] [Warning] Found boosting=goss. For backwards compatibility reasons, LightGBM interprets this as boosting=gbdt, data_sample_strategy=goss.To suppress this warning, set data_sample_strategy=goss instead.
# [LightGBM] [Warning] Found boosting=goss. For backwards compatibility reasons, LightGBM interprets this as boosting=gbdt, data_sample_strategy=goss.To suppress this warning, set data_sample_strategy=goss instead.
# [LightGBM] [Info] Number of positive: 5373, number of negative: 3231
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004495 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 361
# [LightGBM] [Info] Number of data points in the train set: 8604, number of used features: 99
# [LightGBM] [Info] Using GOSS
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.624477 -> initscore=0.508595
# [LightGBM] [Info] Start training from score 0.508595
# [LightGBM] [Warning] Found boosting=goss. For backwards compatibility reasons, LightGBM interprets this as boosting=gbdt, data_sample_strategy=goss.To suppress this warning, set data_sample_strategy=goss instead.
# [LightGBM] [Warning] Found boosting=goss. For backwards compatibility reasons, LightGBM interprets this as boosting=gbdt, data_sample_strategy=goss.To suppress this warning, set data_sample_strategy=goss instead.
# [LightGBM] [Warning] Found boosting=goss. For backwards compatibility reasons, LightGBM interprets this as boosting=gbdt, data_sample_strategy=goss.To suppress this warning, set data_sample_strategy=goss instead.
# [LightGBM] [Info] Number of positive: 5373, number of negative: 3231
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004323 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 364
# [LightGBM] [Info] Number of data points in the train set: 8604, number of used features: 100
# [LightGBM] [Info] Using GOSS
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.624477 -> initscore=0.508595
# [LightGBM] [Info] Start training from score 0.508595
# [LightGBM] [Warning] Found boosting=goss. For backwards compatibility reasons, LightGBM interprets this as boosting=gbdt, data_sample_strategy=goss.To suppress this warning, set data_sample_strategy=goss instead.
# [LightGBM] [Warning] Found boosting=goss. For backwards compatibility reasons, LightGBM interprets this as boosting=gbdt, data_sample_strategy=goss.To suppress this warning, set data_sample_strategy=goss instead.
# [LightGBM] [Warning] Found boosting=goss. For backwards compatibility reasons, LightGBM interprets this as boosting=gbdt, data_sample_strategy=goss.To suppress this warning, set data_sample_strategy=goss instead.
# [LightGBM] [Info] Number of positive: 5374, number of negative: 3230
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003548 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 360
# [LightGBM] [Info] Number of data points in the train set: 8604, number of used features: 99
# [LightGBM] [Info] Using GOSS
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.624593 -> initscore=0.509090
# [LightGBM] [Info] Start training from score 0.509090
# [LightGBM] [Warning] Found boosting=goss. For backwards compatibility reasons, LightGBM interprets this as boosting=gbdt, data_sample_strategy=goss.To suppress this warning, set data_sample_strategy=goss instead.
# [LightGBM] [Info] Number of positive: 5373, number of negative: 3231
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004359 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 361
# [LightGBM] [Info] Number of data points in the train set: 8604, number of used features: 99
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.624477 -> initscore=0.508595
# [LightGBM] [Info] Start training from score 0.508595
# [LightGBM] [Info] Number of positive: 5373, number of negative: 3231
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004634 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 364
# [LightGBM] [Info] Number of data points in the train set: 8604, number of used features: 100
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.624477 -> initscore=0.508595
# [LightGBM] [Info] Start training from score 0.508595
# [LightGBM] [Info] Number of positive: 5374, number of negative: 3230
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004429 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 360
# [LightGBM] [Info] Number of data points in the train set: 8604, number of used features: 99
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.624593 -> initscore=0.509090
# [LightGBM] [Info] Start training from score 0.509090
# [LightGBM] [Info] Number of positive: 5373, number of negative: 3231
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005235 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 430
# [LightGBM] [Info] Number of data points in the train set: 8604, number of used features: 122
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.624477 -> initscore=0.508595
# [LightGBM] [Info] Start training from score 0.508595
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 5373, number of negative: 3231
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005103 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 424
# [LightGBM] [Info] Number of data points in the train set: 8604, number of used features: 120
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.624477 -> initscore=0.508595
# [LightGBM] [Info] Start training from score 0.508595
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 5374, number of negative: 3230
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004398 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 414
# [LightGBM] [Info] Number of data points in the train set: 8604, number of used features: 117
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.624593 -> initscore=0.509090
# [LightGBM] [Info] Start training from score 0.509090
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Found boosting=goss. For backwards compatibility reasons, LightGBM interprets this as boosting=gbdt, data_sample_strategy=goss.To suppress this warning, set data_sample_strategy=goss instead.
# [LightGBM] [Warning] Found boosting=goss. For backwards compatibility reasons, LightGBM interprets this as boosting=gbdt, data_sample_strategy=goss.To suppress this warning, set data_sample_strategy=goss instead.
# [LightGBM] [Info] Number of positive: 5373, number of negative: 3231
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002938 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 361
# [LightGBM] [Info] Number of data points in the train set: 8604, number of used features: 99
# [LightGBM] [Info] Using GOSS
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.624477 -> initscore=0.508595
# [LightGBM] [Info] Start training from score 0.508595
# [LightGBM] [Warning] Found boosting=goss. For backwards compatibility reasons, LightGBM interprets this as boosting=gbdt, data_sample_strategy=goss.To suppress this warning, set data_sample_strategy=goss instead.
# [LightGBM] [Warning] Found boosting=goss. For backwards compatibility reasons, LightGBM interprets this as boosting=gbdt, data_sample_strategy=goss.To suppress this warning, set data_sample_strategy=goss instead.
# [LightGBM] [Warning] Found boosting=goss. For backwards compatibility reasons, LightGBM interprets this as boosting=gbdt, data_sample_strategy=goss.To suppress this warning, set data_sample_strategy=goss instead.
# [LightGBM] [Info] Number of positive: 5373, number of negative: 3231
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003691 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 364
# [LightGBM] [Info] Number of data points in the train set: 8604, number of used features: 100
# [LightGBM] [Info] Using GOSS
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.624477 -> initscore=0.508595
# [LightGBM] [Info] Start training from score 0.508595
# [LightGBM] [Warning] Found boosting=goss. For backwards compatibility reasons, LightGBM interprets this as boosting=gbdt, data_sample_strategy=goss.To suppress this warning, set data_sample_strategy=goss instead.
# [LightGBM] [Warning] Found boosting=goss. For backwards compatibility reasons, LightGBM interprets this as boosting=gbdt, data_sample_strategy=goss.To suppress this warning, set data_sample_strategy=goss instead.
# [LightGBM] [Warning] Found boosting=goss. For backwards compatibility reasons, LightGBM interprets this as boosting=gbdt, data_sample_strategy=goss.To suppress this warning, set data_sample_strategy=goss instead.
# [LightGBM] [Info] Number of positive: 5374, number of negative: 3230
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004200 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 360
# [LightGBM] [Info] Number of data points in the train set: 8604, number of used features: 99
# [LightGBM] [Info] Using GOSS
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.624593 -> initscore=0.509090
# [LightGBM] [Info] Start training from score 0.509090
# [LightGBM] [Warning] Found boosting=goss. For backwards compatibility reasons, LightGBM interprets this as boosting=gbdt, data_sample_strategy=goss.To suppress this warning, set data_sample_strategy=goss instead.
# [LightGBM] [Info] Number of positive: 5373, number of negative: 3231
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003603 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 385
# [LightGBM] [Info] Number of data points in the train set: 8604, number of used features: 107
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.624477 -> initscore=0.508595
# [LightGBM] [Info] Start training from score 0.508595
# [LightGBM] [Info] Number of positive: 5373, number of negative: 3231
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004595 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 379
# [LightGBM] [Info] Number of data points in the train set: 8604, number of used features: 105
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.624477 -> initscore=0.508595
# [LightGBM] [Info] Start training from score 0.508595
# [LightGBM] [Info] Number of positive: 5374, number of negative: 3230
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002840 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 384
# [LightGBM] [Info] Number of data points in the train set: 8604, number of used features: 107
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.624593 -> initscore=0.509090
# [LightGBM] [Info] Start training from score 0.509090
# [LightGBM] [Warning] Found boosting=goss. For backwards compatibility reasons, LightGBM interprets this as boosting=gbdt, data_sample_strategy=goss.To suppress this warning, set data_sample_strategy=goss instead.
# [LightGBM] [Warning] Found boosting=goss. For backwards compatibility reasons, LightGBM interprets this as boosting=gbdt, data_sample_strategy=goss.To suppress this warning, set data_sample_strategy=goss instead.
# [LightGBM] [Info] Number of positive: 5373, number of negative: 3231
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004317 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 430
# [LightGBM] [Info] Number of data points in the train set: 8604, number of used features: 122
# [LightGBM] [Info] Using GOSS
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.624477 -> initscore=0.508595
# [LightGBM] [Info] Start training from score 0.508595
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Found boosting=goss. For backwards compatibility reasons, LightGBM interprets this as boosting=gbdt, data_sample_strategy=goss.To suppress this warning, set data_sample_strategy=goss instead.
# [LightGBM] [Warning] Found boosting=goss. For backwards compatibility reasons, LightGBM interprets this as boosting=gbdt, data_sample_strategy=goss.To suppress this warning, set data_sample_strategy=goss instead.
# [LightGBM] [Info] Number of positive: 5373, number of negative: 3231
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004347 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 385
# [LightGBM] [Info] Number of data points in the train set: 8604, number of used features: 107
# [LightGBM] [Info] Using GOSS
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.624477 -> initscore=0.508595
# [LightGBM] [Info] Start training from score 0.508595
# [LightGBM] [Warning] Found boosting=goss. For backwards compatibility reasons, LightGBM interprets this as boosting=gbdt, data_sample_strategy=goss.To suppress this warning, set data_sample_strategy=goss instead.
# [LightGBM] [Warning] Found boosting=goss. For backwards compatibility reasons, LightGBM interprets this as boosting=gbdt, data_sample_strategy=goss.To suppress this warning, set data_sample_strategy=goss instead.
# [LightGBM] [Warning] Found boosting=goss. For backwards compatibility reasons, LightGBM interprets this as boosting=gbdt, data_sample_strategy=goss.To suppress this warning, set data_sample_strategy=goss instead.
# [LightGBM] [Info] Number of positive: 5373, number of negative: 3231
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003149 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 379
# [LightGBM] [Info] Number of data points in the train set: 8604, number of used features: 105
# [LightGBM] [Info] Using GOSS
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.624477 -> initscore=0.508595
# [LightGBM] [Info] Start training from score 0.508595
# [LightGBM] [Warning] Found boosting=goss. For backwards compatibility reasons, LightGBM interprets this as boosting=gbdt, data_sample_strategy=goss.To suppress this warning, set data_sample_strategy=goss instead.
# [LightGBM] [Warning] Found boosting=goss. For backwards compatibility reasons, LightGBM interprets this as boosting=gbdt, data_sample_strategy=goss.To suppress this warning, set data_sample_strategy=goss instead.
# [LightGBM] [Warning] Found boosting=goss. For backwards compatibility reasons, LightGBM interprets this as boosting=gbdt, data_sample_strategy=goss.To suppress this warning, set data_sample_strategy=goss instead.
# [LightGBM] [Info] Number of positive: 5374, number of negative: 3230
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003489 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 384
# [LightGBM] [Info] Number of data points in the train set: 8604, number of used features: 107
# [LightGBM] [Info] Using GOSS
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.624593 -> initscore=0.509090
# [LightGBM] [Info] Start training from score 0.509090
# [LightGBM] [Warning] Found boosting=goss. For backwards compatibility reasons, LightGBM interprets this as boosting=gbdt, data_sample_strategy=goss.To suppress this warning, set data_sample_strategy=goss instead.
# [LightGBM] [Info] Number of positive: 8060, number of negative: 4846
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004186 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 383
# [LightGBM] [Info] Number of data points in the train set: 12906, number of used features: 106
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.624516 -> initscore=0.508760
# [LightGBM] [Info] Start training from score 0.508760
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# Elapsed Time: 0 minutes and 18.378279209136963 seconds
#
# Best Parameters:  {'subsample': 0.8, 'num_leaves': 50, 'n_estimators': 150, 'min_child_samples': 15, 'max_depth': 5, 'learning_rate': 0.05, 'colsample_bytree': 1.0, 'boosting_type': 'gbdt'}
#
# Best Accuracy: 0.81

# %%
# # create the lgbm model using the winning parameters
# best_model = random_search.best_estimator_
# best_model.fit(X_train, y_train)

# # get the probabilities using the test data
# probabilities = best_model.predict_proba(X_test)

# print (probabilities)

# # create df for submission
# sub_df = test_df[['patient_id']]
# sub_df['DiagPeriodL90D'] = probabilities[:,1]

# # save the submission
# display(sub_df)

# sub_df.to_csv('simplified_submission_lgbm_' + str(iteration3) + '.csv', index=False)
# Out:
# [LightGBM] [Info] Number of positive: 8060, number of negative: 4846
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004650 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 383
# [LightGBM] [Info] Number of data points in the train set: 12906, number of used features: 106
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.624516 -> initscore=0.508760
# [LightGBM] [Info] Start training from score 0.508760
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [[0.22160413 0.77839587]
#  [0.22109297 0.77890703]
#  [0.21785651 0.78214349]
#  ...
#  [0.11660875 0.88339125]
#  [0.91110947 0.08889053]
#  [0.13328235 0.86671765]]
# C:\Users\parth\AppData\Local\Temp\ipykernel_13088\61004080.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df['DiagPeriodL90D'] = probabilities[:,1]
#       patient_id  DiagPeriodL90D
# 0         573710        0.778396
# 1         593679        0.778907
# 2         184532        0.782143
# 3         447383        0.775616
# 4         687972        0.789174
# ...          ...             ...
# 5787      977076        0.803716
# 5788      922960        0.840161
# 5789      759690        0.883391
# 5790      911717        0.088891
# 5791      327597        0.866718
#
# [5792 rows x 2 columns]

# %%
# LOGGING 2/24/24 -- NOTE THAT ANY SUBMISSIONS NAMED _LBGM WERE ACTUALLY CATBOOST
# test 0 - random_state = None, n_iter = 20
# test 1 - random_state = 26, n_iter = 15
# test2 - random_state = 52, n_iter = 15

# %%
# iteration4 = 0

# %%
# # trying a combination of catboost and lgbm
# start_time = time.time() # start timer

# lgbm_classifier, catboost_classifier = LGBMClassifier(), CatBoostClassifier()

# # train both models
# lgbm_classifier.fit(X_train, y_train)
# catboost_classifier.fit(X_train, y_train)

# end_time = time.time() # end the timer
# elapsed_time_seconds = end_time - start_time

# # print the elapsed time
# print(f"\nElapsed Time: {int(elapsed_time_seconds // 60)} minutes and {elapsed_time_seconds % 60} seconds")

# # print the score of the models
# print("CatBoost Score:", catboost_classifier.best_score_)
# print("LGBM Score:", lgbm_classifier.best_score_)


# iteration4 += 1
# Out:
# [LightGBM] [Info] Number of positive: 8060, number of negative: 4846
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.007164 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 371
# [LightGBM] [Info] Number of data points in the train set: 12906, number of used features: 102
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.624516 -> initscore=0.508760
# [LightGBM] [Info] Start training from score 0.508760
# Learning rate set to 0.030707
# 0:	learn: 0.6797426	total: 46.7ms	remaining: 46.7s
# 1:	learn: 0.6668742	total: 64.3ms	remaining: 32.1s
# 2:	learn: 0.6547937	total: 81.5ms	remaining: 27.1s
# 3:	learn: 0.6430810	total: 97.4ms	remaining: 24.2s
# 4:	learn: 0.6329168	total: 113ms	remaining: 22.5s
# 5:	learn: 0.6235054	total: 129ms	remaining: 21.3s
# 6:	learn: 0.6135758	total: 142ms	remaining: 20.2s
# 7:	learn: 0.6055002	total: 158ms	remaining: 19.6s
# 8:	learn: 0.5978745	total: 174ms	remaining: 19.1s
# 9:	learn: 0.5904694	total: 189ms	remaining: 18.7s
# 10:	learn: 0.5834992	total: 206ms	remaining: 18.5s
# 11:	learn: 0.5763164	total: 222ms	remaining: 18.2s
# 12:	learn: 0.5708199	total: 238ms	remaining: 18s
# 13:	learn: 0.5648553	total: 254ms	remaining: 17.9s
# 14:	learn: 0.5591672	total: 271ms	remaining: 17.8s
# 15:	learn: 0.5541023	total: 288ms	remaining: 17.7s
# 16:	learn: 0.5495586	total: 303ms	remaining: 17.5s
# 17:	learn: 0.5453323	total: 318ms	remaining: 17.4s
# 18:	learn: 0.5412101	total: 335ms	remaining: 17.3s
# 19:	learn: 0.5373240	total: 349ms	remaining: 17.1s
# 20:	learn: 0.5341351	total: 366ms	remaining: 17.1s
# 21:	learn: 0.5307078	total: 383ms	remaining: 17s
# 22:	learn: 0.5279671	total: 397ms	remaining: 16.9s
# 23:	learn: 0.5248337	total: 411ms	remaining: 16.7s
# 24:	learn: 0.5220268	total: 426ms	remaining: 16.6s
# 25:	learn: 0.5194840	total: 440ms	remaining: 16.5s
# 26:	learn: 0.5172573	total: 457ms	remaining: 16.5s
# 27:	learn: 0.5151245	total: 472ms	remaining: 16.4s
# 28:	learn: 0.5130226	total: 487ms	remaining: 16.3s
# 29:	learn: 0.5110935	total: 503ms	remaining: 16.3s
# 30:	learn: 0.5090975	total: 519ms	remaining: 16.2s
# 31:	learn: 0.5070797	total: 534ms	remaining: 16.2s
# 32:	learn: 0.5051690	total: 550ms	remaining: 16.1s
# 33:	learn: 0.5032668	total: 564ms	remaining: 16s
# 34:	learn: 0.5014464	total: 579ms	remaining: 16s
# 35:	learn: 0.4999153	total: 595ms	remaining: 15.9s
# 36:	learn: 0.4988052	total: 609ms	remaining: 15.9s
# 37:	learn: 0.4974620	total: 623ms	remaining: 15.8s
# 38:	learn: 0.4962147	total: 640ms	remaining: 15.8s
# 39:	learn: 0.4949557	total: 653ms	remaining: 15.7s
# 40:	learn: 0.4938138	total: 667ms	remaining: 15.6s
# 41:	learn: 0.4928682	total: 681ms	remaining: 15.5s
# 42:	learn: 0.4916829	total: 696ms	remaining: 15.5s
# 43:	learn: 0.4908778	total: 709ms	remaining: 15.4s
# 44:	learn: 0.4899000	total: 724ms	remaining: 15.4s
# 45:	learn: 0.4892485	total: 740ms	remaining: 15.3s
# 46:	learn: 0.4883718	total: 755ms	remaining: 15.3s
# 47:	learn: 0.4876531	total: 772ms	remaining: 15.3s
# 48:	learn: 0.4868515	total: 787ms	remaining: 15.3s
# 49:	learn: 0.4861021	total: 804ms	remaining: 15.3s
# 50:	learn: 0.4853918	total: 818ms	remaining: 15.2s
# 51:	learn: 0.4847577	total: 834ms	remaining: 15.2s
# 52:	learn: 0.4839880	total: 851ms	remaining: 15.2s
# 53:	learn: 0.4835199	total: 869ms	remaining: 15.2s
# 54:	learn: 0.4829839	total: 886ms	remaining: 15.2s
# 55:	learn: 0.4824398	total: 902ms	remaining: 15.2s
# 56:	learn: 0.4817949	total: 917ms	remaining: 15.2s
# 57:	learn: 0.4811957	total: 933ms	remaining: 15.2s
# 58:	learn: 0.4807463	total: 947ms	remaining: 15.1s
# 59:	learn: 0.4803183	total: 962ms	remaining: 15.1s
# 60:	learn: 0.4799993	total: 978ms	remaining: 15.1s
# 61:	learn: 0.4795931	total: 994ms	remaining: 15s
# 62:	learn: 0.4791063	total: 1.01s	remaining: 15s
# 63:	learn: 0.4785814	total: 1.02s	remaining: 14.9s
# 64:	learn: 0.4782305	total: 1.03s	remaining: 14.9s
# 65:	learn: 0.4778599	total: 1.04s	remaining: 14.8s
# 66:	learn: 0.4774369	total: 1.06s	remaining: 14.8s
# 67:	learn: 0.4770732	total: 1.07s	remaining: 14.7s
# 68:	learn: 0.4768879	total: 1.09s	remaining: 14.7s
# 69:	learn: 0.4764568	total: 1.1s	remaining: 14.6s
# 70:	learn: 0.4761066	total: 1.11s	remaining: 14.6s
# 71:	learn: 0.4758139	total: 1.13s	remaining: 14.5s
# 72:	learn: 0.4754890	total: 1.14s	remaining: 14.5s
# 73:	learn: 0.4751787	total: 1.15s	remaining: 14.5s
# 74:	learn: 0.4748826	total: 1.17s	remaining: 14.4s
# 75:	learn: 0.4746351	total: 1.18s	remaining: 14.4s
# 76:	learn: 0.4743665	total: 1.19s	remaining: 14.3s
# 77:	learn: 0.4741385	total: 1.21s	remaining: 14.3s
# 78:	learn: 0.4738888	total: 1.22s	remaining: 14.2s
# 79:	learn: 0.4735486	total: 1.23s	remaining: 14.2s
# 80:	learn: 0.4733333	total: 1.24s	remaining: 14.1s
# 81:	learn: 0.4730563	total: 1.26s	remaining: 14.1s
# 82:	learn: 0.4727958	total: 1.27s	remaining: 14.1s
# 83:	learn: 0.4725659	total: 1.29s	remaining: 14s
# 84:	learn: 0.4722775	total: 1.3s	remaining: 14s
# 85:	learn: 0.4720573	total: 1.31s	remaining: 14s
# 86:	learn: 0.4718935	total: 1.33s	remaining: 13.9s
# 87:	learn: 0.4716863	total: 1.34s	remaining: 13.9s
# 88:	learn: 0.4713985	total: 1.35s	remaining: 13.9s
# 89:	learn: 0.4711487	total: 1.37s	remaining: 13.8s
# 90:	learn: 0.4710709	total: 1.38s	remaining: 13.8s
# 91:	learn: 0.4708187	total: 1.39s	remaining: 13.7s
# 92:	learn: 0.4705195	total: 1.41s	remaining: 13.7s
# 93:	learn: 0.4703042	total: 1.42s	remaining: 13.7s
# 94:	learn: 0.4701223	total: 1.43s	remaining: 13.7s
# 95:	learn: 0.4698210	total: 1.45s	remaining: 13.7s
# 96:	learn: 0.4696483	total: 1.46s	remaining: 13.6s
# 97:	learn: 0.4694937	total: 1.48s	remaining: 13.6s
# 98:	learn: 0.4693117	total: 1.49s	remaining: 13.6s
# 99:	learn: 0.4690864	total: 1.51s	remaining: 13.6s
# 100:	learn: 0.4688502	total: 1.52s	remaining: 13.6s
# 101:	learn: 0.4687021	total: 1.54s	remaining: 13.6s
# 102:	learn: 0.4685653	total: 1.55s	remaining: 13.5s
# 103:	learn: 0.4683287	total: 1.57s	remaining: 13.5s
# 104:	learn: 0.4681143	total: 1.58s	remaining: 13.5s
# 105:	learn: 0.4678567	total: 1.59s	remaining: 13.5s
# 106:	learn: 0.4677052	total: 1.61s	remaining: 13.4s
# 107:	learn: 0.4675356	total: 1.62s	remaining: 13.4s
# 108:	learn: 0.4674351	total: 1.64s	remaining: 13.4s
# 109:	learn: 0.4672524	total: 1.65s	remaining: 13.3s
# 110:	learn: 0.4671195	total: 1.66s	remaining: 13.3s
# 111:	learn: 0.4669467	total: 1.67s	remaining: 13.3s
# 112:	learn: 0.4668037	total: 1.69s	remaining: 13.3s
# 113:	learn: 0.4666301	total: 1.7s	remaining: 13.2s
# 114:	learn: 0.4664843	total: 1.72s	remaining: 13.2s
# 115:	learn: 0.4663788	total: 1.73s	remaining: 13.2s
# 116:	learn: 0.4662393	total: 1.74s	remaining: 13.1s
# 117:	learn: 0.4661386	total: 1.75s	remaining: 13.1s
# 118:	learn: 0.4659637	total: 1.77s	remaining: 13.1s
# 119:	learn: 0.4657516	total: 1.78s	remaining: 13.1s
# 120:	learn: 0.4656337	total: 1.8s	remaining: 13.1s
# 121:	learn: 0.4654579	total: 1.81s	remaining: 13s
# 122:	learn: 0.4652398	total: 1.82s	remaining: 13s
# 123:	learn: 0.4651350	total: 1.84s	remaining: 13s
# 124:	learn: 0.4650218	total: 1.85s	remaining: 13s
# 125:	learn: 0.4648756	total: 1.87s	remaining: 12.9s
# 126:	learn: 0.4646990	total: 1.88s	remaining: 12.9s
# 127:	learn: 0.4646007	total: 1.89s	remaining: 12.9s
# 128:	learn: 0.4644609	total: 1.91s	remaining: 12.9s
# 129:	learn: 0.4643311	total: 1.92s	remaining: 12.9s
# 130:	learn: 0.4642116	total: 1.94s	remaining: 12.9s
# 131:	learn: 0.4640680	total: 1.95s	remaining: 12.8s
# 132:	learn: 0.4639257	total: 1.97s	remaining: 12.8s
# 133:	learn: 0.4638085	total: 1.99s	remaining: 12.8s
# 134:	learn: 0.4637011	total: 2s	remaining: 12.8s
# 135:	learn: 0.4635994	total: 2.02s	remaining: 12.8s
# 136:	learn: 0.4635196	total: 2.03s	remaining: 12.8s
# 137:	learn: 0.4634272	total: 2.05s	remaining: 12.8s
# 138:	learn: 0.4633198	total: 2.06s	remaining: 12.8s
# 139:	learn: 0.4632244	total: 2.07s	remaining: 12.7s
# 140:	learn: 0.4631366	total: 2.09s	remaining: 12.7s
# 141:	learn: 0.4630551	total: 2.1s	remaining: 12.7s
# 142:	learn: 0.4629997	total: 2.12s	remaining: 12.7s
# 143:	learn: 0.4629311	total: 2.14s	remaining: 12.7s
# 144:	learn: 0.4628555	total: 2.15s	remaining: 12.7s
# 145:	learn: 0.4626582	total: 2.17s	remaining: 12.7s
# 146:	learn: 0.4625811	total: 2.18s	remaining: 12.7s
# 147:	learn: 0.4624108	total: 2.2s	remaining: 12.7s
# 148:	learn: 0.4622096	total: 2.21s	remaining: 12.7s
# 149:	learn: 0.4621188	total: 2.23s	remaining: 12.6s
# 150:	learn: 0.4620497	total: 2.25s	remaining: 12.6s
# 151:	learn: 0.4618611	total: 2.26s	remaining: 12.6s
# 152:	learn: 0.4617804	total: 2.28s	remaining: 12.6s
# 153:	learn: 0.4615872	total: 2.29s	remaining: 12.6s
# 154:	learn: 0.4614843	total: 2.31s	remaining: 12.6s
# 155:	learn: 0.4613172	total: 2.32s	remaining: 12.6s
# 156:	learn: 0.4612327	total: 2.33s	remaining: 12.5s
# 157:	learn: 0.4610800	total: 2.35s	remaining: 12.5s
# 158:	learn: 0.4609583	total: 2.37s	remaining: 12.5s
# 159:	learn: 0.4608706	total: 2.38s	remaining: 12.5s
# 160:	learn: 0.4606857	total: 2.39s	remaining: 12.5s
# 161:	learn: 0.4604770	total: 2.41s	remaining: 12.5s
# 162:	learn: 0.4603532	total: 2.42s	remaining: 12.4s
# 163:	learn: 0.4602844	total: 2.44s	remaining: 12.4s
# 164:	learn: 0.4601370	total: 2.45s	remaining: 12.4s
# 165:	learn: 0.4600602	total: 2.47s	remaining: 12.4s
# 166:	learn: 0.4600216	total: 2.48s	remaining: 12.4s
# 167:	learn: 0.4599940	total: 2.49s	remaining: 12.3s
# 168:	learn: 0.4599546	total: 2.5s	remaining: 12.3s
# 169:	learn: 0.4598868	total: 2.52s	remaining: 12.3s
# 170:	learn: 0.4597998	total: 2.53s	remaining: 12.3s
# 171:	learn: 0.4596847	total: 2.55s	remaining: 12.3s
# 172:	learn: 0.4595333	total: 2.56s	remaining: 12.3s
# 173:	learn: 0.4594530	total: 2.58s	remaining: 12.2s
# 174:	learn: 0.4593422	total: 2.59s	remaining: 12.2s
# 175:	learn: 0.4592578	total: 2.6s	remaining: 12.2s
# 176:	learn: 0.4590968	total: 2.62s	remaining: 12.2s
# 177:	learn: 0.4589942	total: 2.63s	remaining: 12.2s
# 178:	learn: 0.4588715	total: 2.65s	remaining: 12.2s
# 179:	learn: 0.4587735	total: 2.66s	remaining: 12.1s
# 180:	learn: 0.4586772	total: 2.68s	remaining: 12.1s
# 181:	learn: 0.4586231	total: 2.69s	remaining: 12.1s
# 182:	learn: 0.4584891	total: 2.71s	remaining: 12.1s
# 183:	learn: 0.4583986	total: 2.72s	remaining: 12.1s
# 184:	learn: 0.4583211	total: 2.74s	remaining: 12.1s
# 185:	learn: 0.4581715	total: 2.76s	remaining: 12.1s
# 186:	learn: 0.4580797	total: 2.77s	remaining: 12s
# 187:	learn: 0.4579574	total: 2.78s	remaining: 12s
# 188:	learn: 0.4578560	total: 2.8s	remaining: 12s
# 189:	learn: 0.4577705	total: 2.81s	remaining: 12s
# 190:	learn: 0.4576773	total: 2.83s	remaining: 12s
# 191:	learn: 0.4576132	total: 2.84s	remaining: 12s
# 192:	learn: 0.4575704	total: 2.86s	remaining: 12s
# 193:	learn: 0.4575063	total: 2.88s	remaining: 11.9s
# 194:	learn: 0.4573906	total: 2.89s	remaining: 11.9s
# 195:	learn: 0.4572742	total: 2.9s	remaining: 11.9s
# 196:	learn: 0.4572220	total: 2.92s	remaining: 11.9s
# 197:	learn: 0.4571634	total: 2.95s	remaining: 11.9s
# 198:	learn: 0.4570842	total: 2.96s	remaining: 11.9s
# 199:	learn: 0.4570093	total: 2.98s	remaining: 11.9s
# 200:	learn: 0.4569474	total: 2.99s	remaining: 11.9s
# 201:	learn: 0.4568750	total: 3.01s	remaining: 11.9s
# 202:	learn: 0.4567934	total: 3.02s	remaining: 11.9s
# 203:	learn: 0.4566872	total: 3.03s	remaining: 11.8s
# 204:	learn: 0.4566310	total: 3.05s	remaining: 11.8s
# 205:	learn: 0.4565904	total: 3.06s	remaining: 11.8s
# 206:	learn: 0.4565032	total: 3.08s	remaining: 11.8s
# 207:	learn: 0.4563929	total: 3.09s	remaining: 11.8s
# 208:	learn: 0.4562933	total: 3.11s	remaining: 11.8s
# 209:	learn: 0.4562195	total: 3.12s	remaining: 11.7s
# 210:	learn: 0.4560570	total: 3.14s	remaining: 11.7s
# 211:	learn: 0.4559695	total: 3.15s	remaining: 11.7s
# 212:	learn: 0.4559086	total: 3.17s	remaining: 11.7s
# 213:	learn: 0.4558434	total: 3.19s	remaining: 11.7s
# 214:	learn: 0.4557389	total: 3.21s	remaining: 11.7s
# 215:	learn: 0.4556811	total: 3.22s	remaining: 11.7s
# 216:	learn: 0.4556015	total: 3.23s	remaining: 11.7s
# 217:	learn: 0.4555300	total: 3.25s	remaining: 11.7s
# 218:	learn: 0.4554880	total: 3.27s	remaining: 11.7s
# 219:	learn: 0.4554438	total: 3.28s	remaining: 11.6s
# 220:	learn: 0.4552479	total: 3.3s	remaining: 11.6s
# 221:	learn: 0.4551251	total: 3.31s	remaining: 11.6s
# 222:	learn: 0.4550209	total: 3.33s	remaining: 11.6s
# 223:	learn: 0.4549722	total: 3.34s	remaining: 11.6s
# 224:	learn: 0.4549003	total: 3.36s	remaining: 11.6s
# 225:	learn: 0.4547727	total: 3.37s	remaining: 11.5s
# 226:	learn: 0.4547090	total: 3.39s	remaining: 11.5s
# 227:	learn: 0.4545923	total: 3.4s	remaining: 11.5s
# 228:	learn: 0.4545480	total: 3.42s	remaining: 11.5s
# 229:	learn: 0.4544607	total: 3.43s	remaining: 11.5s
# 230:	learn: 0.4543881	total: 3.45s	remaining: 11.5s
# 231:	learn: 0.4543361	total: 3.47s	remaining: 11.5s
# 232:	learn: 0.4543039	total: 3.48s	remaining: 11.5s
# 233:	learn: 0.4542452	total: 3.5s	remaining: 11.5s
# 234:	learn: 0.4542067	total: 3.51s	remaining: 11.4s
# 235:	learn: 0.4541040	total: 3.53s	remaining: 11.4s
# 236:	learn: 0.4540377	total: 3.54s	remaining: 11.4s
# 237:	learn: 0.4540028	total: 3.56s	remaining: 11.4s
# 238:	learn: 0.4539153	total: 3.58s	remaining: 11.4s
# 239:	learn: 0.4538524	total: 3.6s	remaining: 11.4s
# 240:	learn: 0.4537631	total: 3.61s	remaining: 11.4s
# 241:	learn: 0.4536916	total: 3.63s	remaining: 11.4s
# 242:	learn: 0.4536410	total: 3.65s	remaining: 11.4s
# 243:	learn: 0.4535871	total: 3.66s	remaining: 11.4s
# 244:	learn: 0.4535321	total: 3.68s	remaining: 11.3s
# 245:	learn: 0.4534669	total: 3.7s	remaining: 11.3s
# 246:	learn: 0.4533789	total: 3.71s	remaining: 11.3s
# 247:	learn: 0.4532841	total: 3.73s	remaining: 11.3s
# 248:	learn: 0.4531654	total: 3.74s	remaining: 11.3s
# 249:	learn: 0.4530956	total: 3.76s	remaining: 11.3s
# 250:	learn: 0.4529988	total: 3.77s	remaining: 11.3s
# 251:	learn: 0.4529380	total: 3.79s	remaining: 11.2s
# 252:	learn: 0.4529022	total: 3.8s	remaining: 11.2s
# 253:	learn: 0.4528500	total: 3.82s	remaining: 11.2s
# 254:	learn: 0.4527908	total: 3.83s	remaining: 11.2s
# 255:	learn: 0.4527545	total: 3.85s	remaining: 11.2s
# 256:	learn: 0.4526475	total: 3.86s	remaining: 11.2s
# 257:	learn: 0.4525389	total: 3.88s	remaining: 11.2s
# 258:	learn: 0.4525001	total: 3.9s	remaining: 11.1s
# 259:	learn: 0.4523438	total: 3.91s	remaining: 11.1s
# 260:	learn: 0.4522747	total: 3.93s	remaining: 11.1s
# 261:	learn: 0.4522395	total: 3.94s	remaining: 11.1s
# 262:	learn: 0.4521833	total: 3.96s	remaining: 11.1s
# 263:	learn: 0.4521264	total: 3.98s	remaining: 11.1s
# 264:	learn: 0.4520370	total: 3.99s	remaining: 11.1s
# 265:	learn: 0.4519667	total: 4s	remaining: 11.1s
# 266:	learn: 0.4519392	total: 4.02s	remaining: 11s
# 267:	learn: 0.4518775	total: 4.04s	remaining: 11s
# 268:	learn: 0.4518245	total: 4.05s	remaining: 11s
# 269:	learn: 0.4517732	total: 4.07s	remaining: 11s
# 270:	learn: 0.4516966	total: 4.08s	remaining: 11s
# 271:	learn: 0.4516508	total: 4.1s	remaining: 11s
# 272:	learn: 0.4515391	total: 4.12s	remaining: 11s
# 273:	learn: 0.4515163	total: 4.13s	remaining: 10.9s
# 274:	learn: 0.4514404	total: 4.15s	remaining: 10.9s
# 275:	learn: 0.4514081	total: 4.16s	remaining: 10.9s
# 276:	learn: 0.4513171	total: 4.17s	remaining: 10.9s
# 277:	learn: 0.4511801	total: 4.19s	remaining: 10.9s
# 278:	learn: 0.4510710	total: 4.2s	remaining: 10.9s
# 279:	learn: 0.4510353	total: 4.21s	remaining: 10.8s
# 280:	learn: 0.4510050	total: 4.23s	remaining: 10.8s
# 281:	learn: 0.4509198	total: 4.24s	remaining: 10.8s
# 282:	learn: 0.4508357	total: 4.26s	remaining: 10.8s
# 283:	learn: 0.4507367	total: 4.27s	remaining: 10.8s
# 284:	learn: 0.4506316	total: 4.28s	remaining: 10.7s
# 285:	learn: 0.4505317	total: 4.3s	remaining: 10.7s
# 286:	learn: 0.4504831	total: 4.31s	remaining: 10.7s
# 287:	learn: 0.4504223	total: 4.33s	remaining: 10.7s
# 288:	learn: 0.4503761	total: 4.34s	remaining: 10.7s
# 289:	learn: 0.4503184	total: 4.36s	remaining: 10.7s
# 290:	learn: 0.4502782	total: 4.37s	remaining: 10.6s
# 291:	learn: 0.4501893	total: 4.38s	remaining: 10.6s
# 292:	learn: 0.4501809	total: 4.4s	remaining: 10.6s
# 293:	learn: 0.4500983	total: 4.41s	remaining: 10.6s
# 294:	learn: 0.4500016	total: 4.43s	remaining: 10.6s
# 295:	learn: 0.4499837	total: 4.45s	remaining: 10.6s
# 296:	learn: 0.4498671	total: 4.46s	remaining: 10.6s
# 297:	learn: 0.4497879	total: 4.48s	remaining: 10.5s
# 298:	learn: 0.4497593	total: 4.5s	remaining: 10.5s
# 299:	learn: 0.4496717	total: 4.51s	remaining: 10.5s
# 300:	learn: 0.4495943	total: 4.53s	remaining: 10.5s
# 301:	learn: 0.4495190	total: 4.54s	remaining: 10.5s
# 302:	learn: 0.4494284	total: 4.56s	remaining: 10.5s
# 303:	learn: 0.4493544	total: 4.57s	remaining: 10.5s
# 304:	learn: 0.4493313	total: 4.58s	remaining: 10.4s
# 305:	learn: 0.4492072	total: 4.6s	remaining: 10.4s
# 306:	learn: 0.4491195	total: 4.62s	remaining: 10.4s
# 307:	learn: 0.4489904	total: 4.63s	remaining: 10.4s
# 308:	learn: 0.4489263	total: 4.64s	remaining: 10.4s
# 309:	learn: 0.4487888	total: 4.66s	remaining: 10.4s
# 310:	learn: 0.4487657	total: 4.67s	remaining: 10.3s
# 311:	learn: 0.4487323	total: 4.69s	remaining: 10.3s
# 312:	learn: 0.4486605	total: 4.7s	remaining: 10.3s
# 313:	learn: 0.4485835	total: 4.71s	remaining: 10.3s
# 314:	learn: 0.4485015	total: 4.73s	remaining: 10.3s
# 315:	learn: 0.4484456	total: 4.74s	remaining: 10.3s
# 316:	learn: 0.4484369	total: 4.75s	remaining: 10.2s
# 317:	learn: 0.4483767	total: 4.77s	remaining: 10.2s
# 318:	learn: 0.4482780	total: 4.79s	remaining: 10.2s
# 319:	learn: 0.4482032	total: 4.8s	remaining: 10.2s
# 320:	learn: 0.4481897	total: 4.81s	remaining: 10.2s
# 321:	learn: 0.4480668	total: 4.82s	remaining: 10.2s
# 322:	learn: 0.4480027	total: 4.84s	remaining: 10.1s
# 323:	learn: 0.4479096	total: 4.85s	remaining: 10.1s
# 324:	learn: 0.4478727	total: 4.86s	remaining: 10.1s
# 325:	learn: 0.4477665	total: 4.88s	remaining: 10.1s
# 326:	learn: 0.4476706	total: 4.89s	remaining: 10.1s
# 327:	learn: 0.4476298	total: 4.9s	remaining: 10s
# 328:	learn: 0.4475369	total: 4.92s	remaining: 10s
# 329:	learn: 0.4474536	total: 4.93s	remaining: 10s
# 330:	learn: 0.4473520	total: 4.94s	remaining: 9.99s
# 331:	learn: 0.4472230	total: 4.96s	remaining: 9.98s
# 332:	learn: 0.4471377	total: 4.97s	remaining: 9.96s
# 333:	learn: 0.4470589	total: 4.99s	remaining: 9.95s
# 334:	learn: 0.4470482	total: 5s	remaining: 9.93s
# 335:	learn: 0.4469551	total: 5.02s	remaining: 9.92s
# 336:	learn: 0.4468610	total: 5.03s	remaining: 9.9s
# 337:	learn: 0.4467365	total: 5.05s	remaining: 9.89s
# 338:	learn: 0.4466768	total: 5.06s	remaining: 9.87s
# 339:	learn: 0.4466326	total: 5.08s	remaining: 9.86s
# 340:	learn: 0.4465254	total: 5.1s	remaining: 9.85s
# 341:	learn: 0.4464001	total: 5.11s	remaining: 9.84s
# 342:	learn: 0.4462442	total: 5.13s	remaining: 9.83s
# 343:	learn: 0.4461343	total: 5.15s	remaining: 9.81s
# 344:	learn: 0.4460423	total: 5.16s	remaining: 9.8s
# 345:	learn: 0.4460284	total: 5.18s	remaining: 9.79s
# 346:	learn: 0.4459372	total: 5.19s	remaining: 9.77s
# 347:	learn: 0.4458240	total: 5.21s	remaining: 9.75s
# 348:	learn: 0.4456863	total: 5.22s	remaining: 9.73s
# 349:	learn: 0.4456214	total: 5.23s	remaining: 9.72s
# 350:	learn: 0.4454504	total: 5.25s	remaining: 9.7s
# 351:	learn: 0.4453803	total: 5.26s	remaining: 9.69s
# 352:	learn: 0.4453686	total: 5.28s	remaining: 9.67s
# 353:	learn: 0.4453573	total: 5.29s	remaining: 9.66s
# 354:	learn: 0.4452539	total: 5.31s	remaining: 9.65s
# 355:	learn: 0.4451291	total: 5.33s	remaining: 9.63s
# 356:	learn: 0.4450060	total: 5.34s	remaining: 9.62s
# 357:	learn: 0.4449147	total: 5.36s	remaining: 9.61s
# 358:	learn: 0.4448220	total: 5.38s	remaining: 9.6s
# 359:	learn: 0.4448130	total: 5.39s	remaining: 9.58s
# 360:	learn: 0.4447369	total: 5.41s	remaining: 9.57s
# 361:	learn: 0.4446505	total: 5.42s	remaining: 9.55s
# 362:	learn: 0.4445667	total: 5.43s	remaining: 9.54s
# 363:	learn: 0.4445126	total: 5.45s	remaining: 9.52s
# 364:	learn: 0.4445000	total: 5.46s	remaining: 9.51s
# 365:	learn: 0.4444868	total: 5.48s	remaining: 9.49s
# 366:	learn: 0.4443825	total: 5.49s	remaining: 9.47s
# 367:	learn: 0.4442694	total: 5.51s	remaining: 9.46s
# 368:	learn: 0.4441830	total: 5.53s	remaining: 9.45s
# 369:	learn: 0.4440642	total: 5.54s	remaining: 9.44s
# 370:	learn: 0.4439358	total: 5.56s	remaining: 9.42s
# 371:	learn: 0.4439234	total: 5.57s	remaining: 9.41s
# 372:	learn: 0.4438433	total: 5.59s	remaining: 9.4s
# 373:	learn: 0.4437363	total: 5.61s	remaining: 9.38s
# 374:	learn: 0.4436287	total: 5.62s	remaining: 9.37s
# 375:	learn: 0.4435787	total: 5.64s	remaining: 9.35s
# 376:	learn: 0.4434257	total: 5.65s	remaining: 9.34s
# 377:	learn: 0.4434152	total: 5.67s	remaining: 9.32s
# 378:	learn: 0.4434038	total: 5.68s	remaining: 9.31s
# 379:	learn: 0.4433245	total: 5.7s	remaining: 9.3s
# 380:	learn: 0.4431662	total: 5.71s	remaining: 9.28s
# 381:	learn: 0.4430857	total: 5.73s	remaining: 9.27s
# 382:	learn: 0.4429682	total: 5.74s	remaining: 9.25s
# 383:	learn: 0.4429267	total: 5.76s	remaining: 9.24s
# 384:	learn: 0.4428503	total: 5.77s	remaining: 9.22s
# 385:	learn: 0.4427199	total: 5.79s	remaining: 9.21s
# 386:	learn: 0.4426103	total: 5.81s	remaining: 9.2s
# 387:	learn: 0.4425998	total: 5.82s	remaining: 9.18s
# 388:	learn: 0.4425062	total: 5.83s	remaining: 9.16s
# 389:	learn: 0.4424407	total: 5.85s	remaining: 9.15s
# 390:	learn: 0.4423748	total: 5.86s	remaining: 9.13s
# 391:	learn: 0.4422811	total: 5.88s	remaining: 9.12s
# 392:	learn: 0.4422591	total: 5.89s	remaining: 9.1s
# 393:	learn: 0.4421778	total: 5.9s	remaining: 9.07s
# 394:	learn: 0.4420592	total: 5.92s	remaining: 9.06s
# 395:	learn: 0.4419829	total: 5.93s	remaining: 9.05s
# 396:	learn: 0.4418434	total: 5.95s	remaining: 9.04s
# 397:	learn: 0.4417514	total: 5.96s	remaining: 9.02s
# 398:	learn: 0.4416536	total: 5.98s	remaining: 9.01s
# 399:	learn: 0.4415913	total: 6s	remaining: 8.99s
# 400:	learn: 0.4414858	total: 6.01s	remaining: 8.98s
# 401:	learn: 0.4413584	total: 6.03s	remaining: 8.97s
# 402:	learn: 0.4412603	total: 6.04s	remaining: 8.95s
# 403:	learn: 0.4412119	total: 6.05s	remaining: 8.93s
# 404:	learn: 0.4411046	total: 6.07s	remaining: 8.91s
# 405:	learn: 0.4409705	total: 6.08s	remaining: 8.9s
# 406:	learn: 0.4408983	total: 6.1s	remaining: 8.88s
# 407:	learn: 0.4408104	total: 6.11s	remaining: 8.87s
# 408:	learn: 0.4407993	total: 6.13s	remaining: 8.85s
# 409:	learn: 0.4407176	total: 6.14s	remaining: 8.84s
# 410:	learn: 0.4406356	total: 6.16s	remaining: 8.82s
# 411:	learn: 0.4405357	total: 6.17s	remaining: 8.81s
# 412:	learn: 0.4404264	total: 6.19s	remaining: 8.79s
# 413:	learn: 0.4403146	total: 6.2s	remaining: 8.78s
# 414:	learn: 0.4402439	total: 6.22s	remaining: 8.77s
# 415:	learn: 0.4402331	total: 6.23s	remaining: 8.75s
# 416:	learn: 0.4401000	total: 6.25s	remaining: 8.74s
# 417:	learn: 0.4400431	total: 6.26s	remaining: 8.72s
# 418:	learn: 0.4399478	total: 6.28s	remaining: 8.71s
# 419:	learn: 0.4398839	total: 6.29s	remaining: 8.69s
# 420:	learn: 0.4398041	total: 6.31s	remaining: 8.68s
# 421:	learn: 0.4397000	total: 6.32s	remaining: 8.66s
# 422:	learn: 0.4396905	total: 6.34s	remaining: 8.64s
# 423:	learn: 0.4396181	total: 6.35s	remaining: 8.63s
# 424:	learn: 0.4395474	total: 6.37s	remaining: 8.62s
# 425:	learn: 0.4395383	total: 6.38s	remaining: 8.6s
# 426:	learn: 0.4394794	total: 6.4s	remaining: 8.59s
# 427:	learn: 0.4394709	total: 6.42s	remaining: 8.57s
# 428:	learn: 0.4393467	total: 6.43s	remaining: 8.55s
# 429:	learn: 0.4392490	total: 6.44s	remaining: 8.54s
# 430:	learn: 0.4391668	total: 6.46s	remaining: 8.53s
# 431:	learn: 0.4390902	total: 6.47s	remaining: 8.51s
# 432:	learn: 0.4390181	total: 6.49s	remaining: 8.49s
# 433:	learn: 0.4388929	total: 6.5s	remaining: 8.48s
# 434:	learn: 0.4387809	total: 6.52s	remaining: 8.46s
# 435:	learn: 0.4387214	total: 6.53s	remaining: 8.45s
# 436:	learn: 0.4386430	total: 6.55s	remaining: 8.43s
# 437:	learn: 0.4385830	total: 6.56s	remaining: 8.42s
# 438:	learn: 0.4384837	total: 6.58s	remaining: 8.4s
# 439:	learn: 0.4384096	total: 6.59s	remaining: 8.39s
# 440:	learn: 0.4383346	total: 6.61s	remaining: 8.37s
# 441:	learn: 0.4382407	total: 6.62s	remaining: 8.36s
# 442:	learn: 0.4381409	total: 6.63s	remaining: 8.34s
# 443:	learn: 0.4380878	total: 6.64s	remaining: 8.32s
# 444:	learn: 0.4379077	total: 6.66s	remaining: 8.31s
# 445:	learn: 0.4378238	total: 6.67s	remaining: 8.29s
# 446:	learn: 0.4377476	total: 6.69s	remaining: 8.27s
# 447:	learn: 0.4376260	total: 6.7s	remaining: 8.26s
# 448:	learn: 0.4375223	total: 6.72s	remaining: 8.24s
# 449:	learn: 0.4373961	total: 6.73s	remaining: 8.23s
# 450:	learn: 0.4372916	total: 6.75s	remaining: 8.22s
# 451:	learn: 0.4371718	total: 6.77s	remaining: 8.2s
# 452:	learn: 0.4371234	total: 6.78s	remaining: 8.19s
# 453:	learn: 0.4370024	total: 6.8s	remaining: 8.18s
# 454:	learn: 0.4369066	total: 6.81s	remaining: 8.16s
# 455:	learn: 0.4368970	total: 6.83s	remaining: 8.15s
# 456:	learn: 0.4368207	total: 6.85s	remaining: 8.13s
# 457:	learn: 0.4367140	total: 6.86s	remaining: 8.12s
# 458:	learn: 0.4365972	total: 6.88s	remaining: 8.11s
# 459:	learn: 0.4364528	total: 6.9s	remaining: 8.1s
# 460:	learn: 0.4363668	total: 6.91s	remaining: 8.08s
# 461:	learn: 0.4362729	total: 6.93s	remaining: 8.07s
# 462:	learn: 0.4361597	total: 6.94s	remaining: 8.05s
# 463:	learn: 0.4360530	total: 6.96s	remaining: 8.04s
# 464:	learn: 0.4358859	total: 6.97s	remaining: 8.03s
# 465:	learn: 0.4357881	total: 6.99s	remaining: 8.01s
# 466:	learn: 0.4357083	total: 7s	remaining: 8s
# 467:	learn: 0.4356415	total: 7.02s	remaining: 7.98s
# 468:	learn: 0.4355637	total: 7.04s	remaining: 7.97s
# 469:	learn: 0.4355556	total: 7.05s	remaining: 7.95s
# 470:	learn: 0.4355474	total: 7.07s	remaining: 7.94s
# 471:	learn: 0.4355386	total: 7.08s	remaining: 7.92s
# 472:	learn: 0.4354520	total: 7.09s	remaining: 7.9s
# 473:	learn: 0.4353848	total: 7.11s	remaining: 7.89s
# 474:	learn: 0.4352764	total: 7.12s	remaining: 7.87s
# 475:	learn: 0.4352028	total: 7.14s	remaining: 7.86s
# 476:	learn: 0.4350950	total: 7.16s	remaining: 7.85s
# 477:	learn: 0.4350186	total: 7.17s	remaining: 7.83s
# 478:	learn: 0.4349258	total: 7.19s	remaining: 7.82s
# 479:	learn: 0.4348508	total: 7.21s	remaining: 7.81s
# 480:	learn: 0.4347929	total: 7.22s	remaining: 7.79s
# 481:	learn: 0.4346966	total: 7.24s	remaining: 7.78s
# 482:	learn: 0.4346247	total: 7.25s	remaining: 7.76s
# 483:	learn: 0.4345506	total: 7.27s	remaining: 7.75s
# 484:	learn: 0.4344570	total: 7.28s	remaining: 7.73s
# 485:	learn: 0.4343741	total: 7.3s	remaining: 7.72s
# 486:	learn: 0.4343149	total: 7.31s	remaining: 7.7s
# 487:	learn: 0.4342235	total: 7.33s	remaining: 7.69s
# 488:	learn: 0.4341066	total: 7.34s	remaining: 7.67s
# 489:	learn: 0.4340982	total: 7.36s	remaining: 7.66s
# 490:	learn: 0.4340461	total: 7.37s	remaining: 7.64s
# 491:	learn: 0.4339552	total: 7.39s	remaining: 7.63s
# 492:	learn: 0.4338582	total: 7.41s	remaining: 7.62s
# 493:	learn: 0.4338121	total: 7.42s	remaining: 7.6s
# 494:	learn: 0.4337487	total: 7.44s	remaining: 7.59s
# 495:	learn: 0.4336896	total: 7.45s	remaining: 7.57s
# 496:	learn: 0.4336010	total: 7.47s	remaining: 7.56s
# 497:	learn: 0.4335420	total: 7.49s	remaining: 7.55s
# 498:	learn: 0.4334587	total: 7.5s	remaining: 7.53s
# 499:	learn: 0.4333793	total: 7.52s	remaining: 7.52s
# 500:	learn: 0.4332773	total: 7.54s	remaining: 7.51s
# 501:	learn: 0.4331837	total: 7.55s	remaining: 7.49s
# 502:	learn: 0.4331755	total: 7.57s	remaining: 7.48s
# 503:	learn: 0.4331095	total: 7.58s	remaining: 7.46s
# 504:	learn: 0.4330420	total: 7.6s	remaining: 7.45s
# 505:	learn: 0.4328974	total: 7.62s	remaining: 7.44s
# 506:	learn: 0.4328085	total: 7.63s	remaining: 7.42s
# 507:	learn: 0.4327211	total: 7.65s	remaining: 7.41s
# 508:	learn: 0.4326567	total: 7.66s	remaining: 7.39s
# 509:	learn: 0.4326494	total: 7.68s	remaining: 7.38s
# 510:	learn: 0.4325693	total: 7.69s	remaining: 7.36s
# 511:	learn: 0.4324959	total: 7.71s	remaining: 7.34s
# 512:	learn: 0.4323790	total: 7.72s	remaining: 7.33s
# 513:	learn: 0.4322916	total: 7.74s	remaining: 7.31s
# 514:	learn: 0.4322190	total: 7.75s	remaining: 7.3s
# 515:	learn: 0.4320996	total: 7.77s	remaining: 7.28s
# 516:	learn: 0.4319909	total: 7.78s	remaining: 7.27s
# 517:	learn: 0.4319045	total: 7.79s	remaining: 7.25s
# 518:	learn: 0.4318447	total: 7.8s	remaining: 7.23s
# 519:	learn: 0.4318038	total: 7.82s	remaining: 7.22s
# 520:	learn: 0.4317230	total: 7.84s	remaining: 7.2s
# 521:	learn: 0.4316713	total: 7.85s	remaining: 7.19s
# 522:	learn: 0.4315994	total: 7.87s	remaining: 7.17s
# 523:	learn: 0.4315051	total: 7.88s	remaining: 7.16s
# 524:	learn: 0.4314250	total: 7.89s	remaining: 7.14s
# 525:	learn: 0.4313282	total: 7.91s	remaining: 7.13s
# 526:	learn: 0.4312664	total: 7.92s	remaining: 7.11s
# 527:	learn: 0.4311716	total: 7.94s	remaining: 7.09s
# 528:	learn: 0.4310744	total: 7.95s	remaining: 7.08s
# 529:	learn: 0.4309809	total: 7.97s	remaining: 7.06s
# 530:	learn: 0.4309484	total: 7.98s	remaining: 7.05s
# 531:	learn: 0.4308886	total: 7.99s	remaining: 7.03s
# 532:	learn: 0.4308037	total: 8.01s	remaining: 7.02s
# 533:	learn: 0.4307212	total: 8.03s	remaining: 7s
# 534:	learn: 0.4306388	total: 8.04s	remaining: 6.99s
# 535:	learn: 0.4305491	total: 8.06s	remaining: 6.97s
# 536:	learn: 0.4304650	total: 8.07s	remaining: 6.96s
# 537:	learn: 0.4304030	total: 8.08s	remaining: 6.94s
# 538:	learn: 0.4303256	total: 8.1s	remaining: 6.93s
# 539:	learn: 0.4302755	total: 8.11s	remaining: 6.91s
# 540:	learn: 0.4301997	total: 8.13s	remaining: 6.9s
# 541:	learn: 0.4301929	total: 8.14s	remaining: 6.88s
# 542:	learn: 0.4301367	total: 8.16s	remaining: 6.87s
# 543:	learn: 0.4300852	total: 8.18s	remaining: 6.85s
# 544:	learn: 0.4299938	total: 8.19s	remaining: 6.84s
# 545:	learn: 0.4299125	total: 8.21s	remaining: 6.82s
# 546:	learn: 0.4298209	total: 8.22s	remaining: 6.81s
# 547:	learn: 0.4298132	total: 8.23s	remaining: 6.79s
# 548:	learn: 0.4297446	total: 8.25s	remaining: 6.78s
# 549:	learn: 0.4297372	total: 8.27s	remaining: 6.76s
# 550:	learn: 0.4297306	total: 8.28s	remaining: 6.75s
# 551:	learn: 0.4296625	total: 8.29s	remaining: 6.73s
# 552:	learn: 0.4295939	total: 8.31s	remaining: 6.72s
# 553:	learn: 0.4295028	total: 8.32s	remaining: 6.7s
# 554:	learn: 0.4294210	total: 8.34s	remaining: 6.68s
# 555:	learn: 0.4293692	total: 8.35s	remaining: 6.67s
# 556:	learn: 0.4293627	total: 8.37s	remaining: 6.66s
# 557:	learn: 0.4292979	total: 8.38s	remaining: 6.64s
# 558:	learn: 0.4292639	total: 8.4s	remaining: 6.63s
# 559:	learn: 0.4291970	total: 8.42s	remaining: 6.61s
# 560:	learn: 0.4291544	total: 8.43s	remaining: 6.6s
# 561:	learn: 0.4290919	total: 8.44s	remaining: 6.58s
# 562:	learn: 0.4290080	total: 8.46s	remaining: 6.57s
# 563:	learn: 0.4289268	total: 8.47s	remaining: 6.55s
# 564:	learn: 0.4288325	total: 8.49s	remaining: 6.54s
# 565:	learn: 0.4287471	total: 8.5s	remaining: 6.52s
# 566:	learn: 0.4287073	total: 8.52s	remaining: 6.5s
# 567:	learn: 0.4286050	total: 8.53s	remaining: 6.49s
# 568:	learn: 0.4285331	total: 8.54s	remaining: 6.47s
# 569:	learn: 0.4284776	total: 8.56s	remaining: 6.46s
# 570:	learn: 0.4283762	total: 8.57s	remaining: 6.44s
# 571:	learn: 0.4283014	total: 8.59s	remaining: 6.42s
# 572:	learn: 0.4282263	total: 8.6s	remaining: 6.41s
# 573:	learn: 0.4281757	total: 8.62s	remaining: 6.39s
# 574:	learn: 0.4280945	total: 8.63s	remaining: 6.38s
# 575:	learn: 0.4280369	total: 8.65s	remaining: 6.37s
# 576:	learn: 0.4279588	total: 8.66s	remaining: 6.35s
# 577:	learn: 0.4279520	total: 8.68s	remaining: 6.34s
# 578:	learn: 0.4278975	total: 8.7s	remaining: 6.32s
# 579:	learn: 0.4278167	total: 8.71s	remaining: 6.31s
# 580:	learn: 0.4277512	total: 8.73s	remaining: 6.29s
# 581:	learn: 0.4276937	total: 8.74s	remaining: 6.28s
# 582:	learn: 0.4276337	total: 8.75s	remaining: 6.26s
# 583:	learn: 0.4275668	total: 8.77s	remaining: 6.25s
# 584:	learn: 0.4274988	total: 8.78s	remaining: 6.23s
# 585:	learn: 0.4274240	total: 8.79s	remaining: 6.21s
# 586:	learn: 0.4273646	total: 8.81s	remaining: 6.2s
# 587:	learn: 0.4272572	total: 8.82s	remaining: 6.18s
# 588:	learn: 0.4271482	total: 8.84s	remaining: 6.17s
# 589:	learn: 0.4271142	total: 8.86s	remaining: 6.16s
# 590:	learn: 0.4270574	total: 8.87s	remaining: 6.14s
# 591:	learn: 0.4269883	total: 8.89s	remaining: 6.13s
# 592:	learn: 0.4268899	total: 8.9s	remaining: 6.11s
# 593:	learn: 0.4268134	total: 8.92s	remaining: 6.1s
# 594:	learn: 0.4267618	total: 8.93s	remaining: 6.08s
# 595:	learn: 0.4267558	total: 8.95s	remaining: 6.06s
# 596:	learn: 0.4266799	total: 8.96s	remaining: 6.05s
# 597:	learn: 0.4266311	total: 8.98s	remaining: 6.03s
# 598:	learn: 0.4265744	total: 8.99s	remaining: 6.02s
# 599:	learn: 0.4264900	total: 9.01s	remaining: 6s
# 600:	learn: 0.4264385	total: 9.02s	remaining: 5.99s
# 601:	learn: 0.4264075	total: 9.04s	remaining: 5.97s
# 602:	learn: 0.4263488	total: 9.05s	remaining: 5.96s
# 603:	learn: 0.4262460	total: 9.07s	remaining: 5.94s
# 604:	learn: 0.4261821	total: 9.08s	remaining: 5.93s
# 605:	learn: 0.4261761	total: 9.09s	remaining: 5.91s
# 606:	learn: 0.4261198	total: 9.11s	remaining: 5.9s
# 607:	learn: 0.4260742	total: 9.12s	remaining: 5.88s
# 608:	learn: 0.4260149	total: 9.14s	remaining: 5.87s
# 609:	learn: 0.4258975	total: 9.15s	remaining: 5.85s
# 610:	learn: 0.4258502	total: 9.16s	remaining: 5.83s
# 611:	learn: 0.4257869	total: 9.18s	remaining: 5.82s
# 612:	learn: 0.4257002	total: 9.19s	remaining: 5.8s
# 613:	learn: 0.4256379	total: 9.21s	remaining: 5.79s
# 614:	learn: 0.4255644	total: 9.22s	remaining: 5.77s
# 615:	learn: 0.4254889	total: 9.24s	remaining: 5.76s
# 616:	learn: 0.4254198	total: 9.25s	remaining: 5.74s
# 617:	learn: 0.4253327	total: 9.26s	remaining: 5.73s
# 618:	learn: 0.4252972	total: 9.28s	remaining: 5.71s
# 619:	learn: 0.4252451	total: 9.29s	remaining: 5.69s
# 620:	learn: 0.4251718	total: 9.3s	remaining: 5.68s
# 621:	learn: 0.4251141	total: 9.32s	remaining: 5.66s
# 622:	learn: 0.4250370	total: 9.33s	remaining: 5.65s
# 623:	learn: 0.4249874	total: 9.35s	remaining: 5.63s
# 624:	learn: 0.4249115	total: 9.36s	remaining: 5.62s
# 625:	learn: 0.4248438	total: 9.37s	remaining: 5.6s
# 626:	learn: 0.4248124	total: 9.39s	remaining: 5.58s
# 627:	learn: 0.4247319	total: 9.4s	remaining: 5.57s
# 628:	learn: 0.4246857	total: 9.42s	remaining: 5.55s
# 629:	learn: 0.4246344	total: 9.43s	remaining: 5.54s
# 630:	learn: 0.4245669	total: 9.45s	remaining: 5.53s
# 631:	learn: 0.4245081	total: 9.47s	remaining: 5.51s
# 632:	learn: 0.4244491	total: 9.48s	remaining: 5.5s
# 633:	learn: 0.4244145	total: 9.49s	remaining: 5.48s
# 634:	learn: 0.4243440	total: 9.51s	remaining: 5.47s
# 635:	learn: 0.4242879	total: 9.52s	remaining: 5.45s
# 636:	learn: 0.4242260	total: 9.54s	remaining: 5.43s
# 637:	learn: 0.4241781	total: 9.55s	remaining: 5.42s
# 638:	learn: 0.4241181	total: 9.57s	remaining: 5.4s
# 639:	learn: 0.4240470	total: 9.58s	remaining: 5.39s
# 640:	learn: 0.4239609	total: 9.6s	remaining: 5.38s
# 641:	learn: 0.4238976	total: 9.61s	remaining: 5.36s
# 642:	learn: 0.4238403	total: 9.63s	remaining: 5.35s
# 643:	learn: 0.4238341	total: 9.64s	remaining: 5.33s
# 644:	learn: 0.4237536	total: 9.66s	remaining: 5.32s
# 645:	learn: 0.4236698	total: 9.68s	remaining: 5.3s
# 646:	learn: 0.4235585	total: 9.69s	remaining: 5.29s
# 647:	learn: 0.4234752	total: 9.71s	remaining: 5.27s
# 648:	learn: 0.4233975	total: 9.72s	remaining: 5.26s
# 649:	learn: 0.4233576	total: 9.74s	remaining: 5.24s
# 650:	learn: 0.4232989	total: 9.75s	remaining: 5.23s
# 651:	learn: 0.4232721	total: 9.77s	remaining: 5.21s
# 652:	learn: 0.4232276	total: 9.78s	remaining: 5.2s
# 653:	learn: 0.4231587	total: 9.79s	remaining: 5.18s
# 654:	learn: 0.4231209	total: 9.81s	remaining: 5.17s
# 655:	learn: 0.4230459	total: 9.82s	remaining: 5.15s
# 656:	learn: 0.4229752	total: 9.84s	remaining: 5.14s
# 657:	learn: 0.4229068	total: 9.85s	remaining: 5.12s
# 658:	learn: 0.4228472	total: 9.87s	remaining: 5.11s
# 659:	learn: 0.4227949	total: 9.88s	remaining: 5.09s
# 660:	learn: 0.4227578	total: 9.9s	remaining: 5.08s
# 661:	learn: 0.4226972	total: 9.91s	remaining: 5.06s
# 662:	learn: 0.4226086	total: 9.93s	remaining: 5.04s
# 663:	learn: 0.4225563	total: 9.94s	remaining: 5.03s
# 664:	learn: 0.4225032	total: 9.95s	remaining: 5.01s
# 665:	learn: 0.4223838	total: 9.97s	remaining: 5s
# 666:	learn: 0.4223406	total: 9.98s	remaining: 4.98s
# 667:	learn: 0.4222937	total: 10s	remaining: 4.97s
# 668:	learn: 0.4222818	total: 10s	remaining: 4.95s
# 669:	learn: 0.4221912	total: 10s	remaining: 4.94s
# 670:	learn: 0.4221287	total: 10s	remaining: 4.92s
# 671:	learn: 0.4220734	total: 10.1s	remaining: 4.91s
# 672:	learn: 0.4220365	total: 10.1s	remaining: 4.9s
# 673:	learn: 0.4219510	total: 10.1s	remaining: 4.88s
# 674:	learn: 0.4219209	total: 10.1s	remaining: 4.87s
# 675:	learn: 0.4218713	total: 10.1s	remaining: 4.85s
# 676:	learn: 0.4218487	total: 10.1s	remaining: 4.84s
# 677:	learn: 0.4217710	total: 10.2s	remaining: 4.82s
# 678:	learn: 0.4217056	total: 10.2s	remaining: 4.81s
# 679:	learn: 0.4216401	total: 10.2s	remaining: 4.79s
# 680:	learn: 0.4215868	total: 10.2s	remaining: 4.78s
# 681:	learn: 0.4214654	total: 10.2s	remaining: 4.76s
# 682:	learn: 0.4213836	total: 10.2s	remaining: 4.75s
# 683:	learn: 0.4213391	total: 10.2s	remaining: 4.73s
# 684:	learn: 0.4212351	total: 10.3s	remaining: 4.72s
# 685:	learn: 0.4211649	total: 10.3s	remaining: 4.7s
# 686:	learn: 0.4210701	total: 10.3s	remaining: 4.68s
# 687:	learn: 0.4210243	total: 10.3s	remaining: 4.67s
# 688:	learn: 0.4210048	total: 10.3s	remaining: 4.66s
# 689:	learn: 0.4209268	total: 10.3s	remaining: 4.64s
# 690:	learn: 0.4208832	total: 10.3s	remaining: 4.63s
# 691:	learn: 0.4208062	total: 10.4s	remaining: 4.61s
# 692:	learn: 0.4207303	total: 10.4s	remaining: 4.6s
# 693:	learn: 0.4206897	total: 10.4s	remaining: 4.58s
# 694:	learn: 0.4206484	total: 10.4s	remaining: 4.57s
# 695:	learn: 0.4205974	total: 10.4s	remaining: 4.55s
# 696:	learn: 0.4205847	total: 10.4s	remaining: 4.54s
# 697:	learn: 0.4205007	total: 10.5s	remaining: 4.52s
# 698:	learn: 0.4204071	total: 10.5s	remaining: 4.51s
# 699:	learn: 0.4203608	total: 10.5s	remaining: 4.49s
# 700:	learn: 0.4202602	total: 10.5s	remaining: 4.48s
# 701:	learn: 0.4202310	total: 10.5s	remaining: 4.46s
# 702:	learn: 0.4201925	total: 10.5s	remaining: 4.45s
# 703:	learn: 0.4201162	total: 10.5s	remaining: 4.43s
# 704:	learn: 0.4200589	total: 10.6s	remaining: 4.42s
# 705:	learn: 0.4199965	total: 10.6s	remaining: 4.4s
# 706:	learn: 0.4199052	total: 10.6s	remaining: 4.39s
# 707:	learn: 0.4198610	total: 10.6s	remaining: 4.37s
# 708:	learn: 0.4198132	total: 10.6s	remaining: 4.36s
# 709:	learn: 0.4197382	total: 10.6s	remaining: 4.34s
# 710:	learn: 0.4196905	total: 10.6s	remaining: 4.33s
# 711:	learn: 0.4196206	total: 10.7s	remaining: 4.31s
# 712:	learn: 0.4195486	total: 10.7s	remaining: 4.29s
# 713:	learn: 0.4195078	total: 10.7s	remaining: 4.28s
# 714:	learn: 0.4194588	total: 10.7s	remaining: 4.26s
# 715:	learn: 0.4194477	total: 10.7s	remaining: 4.25s
# 716:	learn: 0.4193749	total: 10.7s	remaining: 4.23s
# 717:	learn: 0.4193257	total: 10.7s	remaining: 4.22s
# 718:	learn: 0.4192580	total: 10.8s	remaining: 4.2s
# 719:	learn: 0.4191846	total: 10.8s	remaining: 4.19s
# 720:	learn: 0.4191790	total: 10.8s	remaining: 4.17s
# 721:	learn: 0.4191051	total: 10.8s	remaining: 4.16s
# 722:	learn: 0.4190353	total: 10.8s	remaining: 4.14s
# 723:	learn: 0.4189324	total: 10.8s	remaining: 4.13s
# 724:	learn: 0.4188760	total: 10.8s	remaining: 4.11s
# 725:	learn: 0.4188248	total: 10.9s	remaining: 4.1s
# 726:	learn: 0.4187833	total: 10.9s	remaining: 4.08s
# 727:	learn: 0.4187143	total: 10.9s	remaining: 4.07s
# 728:	learn: 0.4186511	total: 10.9s	remaining: 4.05s
# 729:	learn: 0.4185753	total: 10.9s	remaining: 4.04s
# 730:	learn: 0.4185274	total: 10.9s	remaining: 4.02s
# 731:	learn: 0.4185014	total: 10.9s	remaining: 4.01s
# 732:	learn: 0.4184574	total: 11s	remaining: 3.99s
# 733:	learn: 0.4183929	total: 11s	remaining: 3.98s
# 734:	learn: 0.4183529	total: 11s	remaining: 3.96s
# 735:	learn: 0.4183022	total: 11s	remaining: 3.95s
# 736:	learn: 0.4182972	total: 11s	remaining: 3.93s
# 737:	learn: 0.4182397	total: 11s	remaining: 3.92s
# 738:	learn: 0.4181973	total: 11.1s	remaining: 3.9s
# 739:	learn: 0.4181135	total: 11.1s	remaining: 3.89s
# 740:	learn: 0.4180298	total: 11.1s	remaining: 3.87s
# 741:	learn: 0.4179579	total: 11.1s	remaining: 3.86s
# 742:	learn: 0.4178942	total: 11.1s	remaining: 3.84s
# 743:	learn: 0.4178696	total: 11.1s	remaining: 3.83s
# 744:	learn: 0.4178223	total: 11.1s	remaining: 3.81s
# 745:	learn: 0.4177264	total: 11.2s	remaining: 3.8s
# 746:	learn: 0.4176753	total: 11.2s	remaining: 3.79s
# 747:	learn: 0.4176332	total: 11.2s	remaining: 3.77s
# 748:	learn: 0.4175536	total: 11.2s	remaining: 3.75s
# 749:	learn: 0.4174372	total: 11.2s	remaining: 3.74s
# 750:	learn: 0.4173674	total: 11.2s	remaining: 3.72s
# 751:	learn: 0.4173238	total: 11.2s	remaining: 3.71s
# 752:	learn: 0.4173016	total: 11.3s	remaining: 3.69s
# 753:	learn: 0.4172573	total: 11.3s	remaining: 3.68s
# 754:	learn: 0.4171405	total: 11.3s	remaining: 3.66s
# 755:	learn: 0.4170586	total: 11.3s	remaining: 3.65s
# 756:	learn: 0.4170127	total: 11.3s	remaining: 3.63s
# 757:	learn: 0.4169377	total: 11.3s	remaining: 3.62s
# 758:	learn: 0.4168789	total: 11.3s	remaining: 3.6s
# 759:	learn: 0.4167835	total: 11.4s	remaining: 3.59s
# 760:	learn: 0.4167367	total: 11.4s	remaining: 3.57s
# 761:	learn: 0.4167317	total: 11.4s	remaining: 3.56s
# 762:	learn: 0.4166948	total: 11.4s	remaining: 3.54s
# 763:	learn: 0.4166317	total: 11.4s	remaining: 3.53s
# 764:	learn: 0.4166020	total: 11.4s	remaining: 3.51s
# 765:	learn: 0.4165629	total: 11.4s	remaining: 3.49s
# 766:	learn: 0.4164944	total: 11.5s	remaining: 3.48s
# 767:	learn: 0.4164366	total: 11.5s	remaining: 3.46s
# 768:	learn: 0.4163669	total: 11.5s	remaining: 3.45s
# 769:	learn: 0.4163245	total: 11.5s	remaining: 3.43s
# 770:	learn: 0.4162259	total: 11.5s	remaining: 3.42s
# 771:	learn: 0.4161649	total: 11.5s	remaining: 3.4s
# 772:	learn: 0.4160853	total: 11.5s	remaining: 3.39s
# 773:	learn: 0.4160253	total: 11.6s	remaining: 3.37s
# 774:	learn: 0.4159683	total: 11.6s	remaining: 3.36s
# 775:	learn: 0.4158511	total: 11.6s	remaining: 3.34s
# 776:	learn: 0.4157784	total: 11.6s	remaining: 3.33s
# 777:	learn: 0.4157303	total: 11.6s	remaining: 3.31s
# 778:	learn: 0.4156076	total: 11.6s	remaining: 3.3s
# 779:	learn: 0.4155925	total: 11.6s	remaining: 3.28s
# 780:	learn: 0.4155129	total: 11.7s	remaining: 3.27s
# 781:	learn: 0.4154388	total: 11.7s	remaining: 3.25s
# 782:	learn: 0.4153812	total: 11.7s	remaining: 3.24s
# 783:	learn: 0.4153131	total: 11.7s	remaining: 3.22s
# 784:	learn: 0.4152274	total: 11.7s	remaining: 3.21s
# 785:	learn: 0.4151874	total: 11.7s	remaining: 3.19s
# 786:	learn: 0.4151117	total: 11.7s	remaining: 3.18s
# 787:	learn: 0.4150085	total: 11.8s	remaining: 3.16s
# 788:	learn: 0.4149376	total: 11.8s	remaining: 3.15s
# 789:	learn: 0.4148632	total: 11.8s	remaining: 3.13s
# 790:	learn: 0.4147790	total: 11.8s	remaining: 3.12s
# 791:	learn: 0.4147697	total: 11.8s	remaining: 3.1s
# 792:	learn: 0.4146955	total: 11.8s	remaining: 3.09s
# 793:	learn: 0.4146908	total: 11.8s	remaining: 3.07s
# 794:	learn: 0.4146152	total: 11.9s	remaining: 3.06s
# 795:	learn: 0.4145583	total: 11.9s	remaining: 3.04s
# 796:	learn: 0.4145388	total: 11.9s	remaining: 3.03s
# 797:	learn: 0.4145113	total: 11.9s	remaining: 3.01s
# 798:	learn: 0.4144483	total: 11.9s	remaining: 3s
# 799:	learn: 0.4143977	total: 11.9s	remaining: 2.98s
# 800:	learn: 0.4143203	total: 11.9s	remaining: 2.97s
# 801:	learn: 0.4142686	total: 12s	remaining: 2.95s
# 802:	learn: 0.4142128	total: 12s	remaining: 2.94s
# 803:	learn: 0.4141129	total: 12s	remaining: 2.92s
# 804:	learn: 0.4140338	total: 12s	remaining: 2.91s
# 805:	learn: 0.4139867	total: 12s	remaining: 2.89s
# 806:	learn: 0.4139453	total: 12s	remaining: 2.88s
# 807:	learn: 0.4139404	total: 12s	remaining: 2.86s
# 808:	learn: 0.4138400	total: 12.1s	remaining: 2.85s
# 809:	learn: 0.4137751	total: 12.1s	remaining: 2.83s
# 810:	learn: 0.4136996	total: 12.1s	remaining: 2.82s
# 811:	learn: 0.4136705	total: 12.1s	remaining: 2.8s
# 812:	learn: 0.4136555	total: 12.1s	remaining: 2.79s
# 813:	learn: 0.4135700	total: 12.1s	remaining: 2.77s
# 814:	learn: 0.4135131	total: 12.2s	remaining: 2.76s
# 815:	learn: 0.4134555	total: 12.2s	remaining: 2.74s
# 816:	learn: 0.4133734	total: 12.2s	remaining: 2.73s
# 817:	learn: 0.4133229	total: 12.2s	remaining: 2.71s
# 818:	learn: 0.4132575	total: 12.2s	remaining: 2.7s
# 819:	learn: 0.4132085	total: 12.2s	remaining: 2.68s
# 820:	learn: 0.4131276	total: 12.2s	remaining: 2.67s
# 821:	learn: 0.4131193	total: 12.3s	remaining: 2.65s
# 822:	learn: 0.4130702	total: 12.3s	remaining: 2.64s
# 823:	learn: 0.4130638	total: 12.3s	remaining: 2.62s
# 824:	learn: 0.4130354	total: 12.3s	remaining: 2.61s
# 825:	learn: 0.4129765	total: 12.3s	remaining: 2.59s
# 826:	learn: 0.4129012	total: 12.3s	remaining: 2.58s
# 827:	learn: 0.4128043	total: 12.3s	remaining: 2.56s
# 828:	learn: 0.4127447	total: 12.4s	remaining: 2.55s
# 829:	learn: 0.4126982	total: 12.4s	remaining: 2.53s
# 830:	learn: 0.4126251	total: 12.4s	remaining: 2.52s
# 831:	learn: 0.4125694	total: 12.4s	remaining: 2.5s
# 832:	learn: 0.4125236	total: 12.4s	remaining: 2.49s
# 833:	learn: 0.4124704	total: 12.4s	remaining: 2.47s
# 834:	learn: 0.4124476	total: 12.4s	remaining: 2.46s
# 835:	learn: 0.4123614	total: 12.5s	remaining: 2.44s
# 836:	learn: 0.4122772	total: 12.5s	remaining: 2.43s
# 837:	learn: 0.4122400	total: 12.5s	remaining: 2.42s
# 838:	learn: 0.4121542	total: 12.5s	remaining: 2.4s
# 839:	learn: 0.4121152	total: 12.5s	remaining: 2.38s
# 840:	learn: 0.4120701	total: 12.5s	remaining: 2.37s
# 841:	learn: 0.4120330	total: 12.5s	remaining: 2.35s
# 842:	learn: 0.4120285	total: 12.6s	remaining: 2.34s
# 843:	learn: 0.4119883	total: 12.6s	remaining: 2.32s
# 844:	learn: 0.4119236	total: 12.6s	remaining: 2.31s
# 845:	learn: 0.4119194	total: 12.6s	remaining: 2.29s
# 846:	learn: 0.4118659	total: 12.6s	remaining: 2.28s
# 847:	learn: 0.4118239	total: 12.6s	remaining: 2.26s
# 848:	learn: 0.4117689	total: 12.6s	remaining: 2.25s
# 849:	learn: 0.4117242	total: 12.7s	remaining: 2.23s
# 850:	learn: 0.4117160	total: 12.7s	remaining: 2.22s
# 851:	learn: 0.4116642	total: 12.7s	remaining: 2.2s
# 852:	learn: 0.4115915	total: 12.7s	remaining: 2.19s
# 853:	learn: 0.4115430	total: 12.7s	remaining: 2.17s
# 854:	learn: 0.4114670	total: 12.7s	remaining: 2.16s
# 855:	learn: 0.4114234	total: 12.7s	remaining: 2.14s
# 856:	learn: 0.4113660	total: 12.8s	remaining: 2.13s
# 857:	learn: 0.4112741	total: 12.8s	remaining: 2.11s
# 858:	learn: 0.4112159	total: 12.8s	remaining: 2.1s
# 859:	learn: 0.4111497	total: 12.8s	remaining: 2.08s
# 860:	learn: 0.4110845	total: 12.8s	remaining: 2.07s
# 861:	learn: 0.4110804	total: 12.8s	remaining: 2.05s
# 862:	learn: 0.4110068	total: 12.8s	remaining: 2.04s
# 863:	learn: 0.4109687	total: 12.9s	remaining: 2.02s
# 864:	learn: 0.4108938	total: 12.9s	remaining: 2.01s
# 865:	learn: 0.4108377	total: 12.9s	remaining: 1.99s
# 866:	learn: 0.4107922	total: 12.9s	remaining: 1.98s
# 867:	learn: 0.4107432	total: 12.9s	remaining: 1.96s
# 868:	learn: 0.4107041	total: 12.9s	remaining: 1.95s
# 869:	learn: 0.4106421	total: 12.9s	remaining: 1.93s
# 870:	learn: 0.4105627	total: 13s	remaining: 1.92s
# 871:	learn: 0.4104795	total: 13s	remaining: 1.9s
# 872:	learn: 0.4104111	total: 13s	remaining: 1.89s
# 873:	learn: 0.4103793	total: 13s	remaining: 1.88s
# 874:	learn: 0.4103089	total: 13s	remaining: 1.86s
# 875:	learn: 0.4102457	total: 13s	remaining: 1.84s
# 876:	learn: 0.4101828	total: 13s	remaining: 1.83s
# 877:	learn: 0.4101316	total: 13.1s	remaining: 1.81s
# 878:	learn: 0.4100989	total: 13.1s	remaining: 1.8s
# 879:	learn: 0.4099854	total: 13.1s	remaining: 1.78s
# 880:	learn: 0.4099416	total: 13.1s	remaining: 1.77s
# 881:	learn: 0.4098775	total: 13.1s	remaining: 1.75s
# 882:	learn: 0.4098018	total: 13.1s	remaining: 1.74s
# 883:	learn: 0.4097722	total: 13.1s	remaining: 1.73s
# 884:	learn: 0.4097427	total: 13.2s	remaining: 1.71s
# 885:	learn: 0.4096818	total: 13.2s	remaining: 1.7s
# 886:	learn: 0.4096372	total: 13.2s	remaining: 1.68s
# 887:	learn: 0.4095717	total: 13.2s	remaining: 1.67s
# 888:	learn: 0.4095219	total: 13.2s	remaining: 1.65s
# 889:	learn: 0.4094781	total: 13.2s	remaining: 1.64s
# 890:	learn: 0.4094155	total: 13.3s	remaining: 1.62s
# 891:	learn: 0.4093435	total: 13.3s	remaining: 1.61s
# 892:	learn: 0.4093160	total: 13.3s	remaining: 1.59s
# 893:	learn: 0.4092602	total: 13.3s	remaining: 1.58s
# 894:	learn: 0.4091601	total: 13.3s	remaining: 1.56s
# 895:	learn: 0.4091087	total: 13.3s	remaining: 1.55s
# 896:	learn: 0.4090132	total: 13.3s	remaining: 1.53s
# 897:	learn: 0.4089351	total: 13.3s	remaining: 1.52s
# 898:	learn: 0.4089311	total: 13.4s	remaining: 1.5s
# 899:	learn: 0.4088837	total: 13.4s	remaining: 1.49s
# 900:	learn: 0.4088246	total: 13.4s	remaining: 1.47s
# 901:	learn: 0.4087574	total: 13.4s	remaining: 1.46s
# 902:	learn: 0.4087158	total: 13.4s	remaining: 1.44s
# 903:	learn: 0.4086748	total: 13.4s	remaining: 1.43s
# 904:	learn: 0.4086227	total: 13.4s	remaining: 1.41s
# 905:	learn: 0.4085952	total: 13.5s	remaining: 1.4s
# 906:	learn: 0.4085363	total: 13.5s	remaining: 1.38s
# 907:	learn: 0.4084750	total: 13.5s	remaining: 1.37s
# 908:	learn: 0.4084361	total: 13.5s	remaining: 1.35s
# 909:	learn: 0.4084029	total: 13.5s	remaining: 1.33s
# 910:	learn: 0.4083286	total: 13.5s	remaining: 1.32s
# 911:	learn: 0.4082782	total: 13.5s	remaining: 1.31s
# 912:	learn: 0.4082059	total: 13.6s	remaining: 1.29s
# 913:	learn: 0.4081393	total: 13.6s	remaining: 1.28s
# 914:	learn: 0.4080527	total: 13.6s	remaining: 1.26s
# 915:	learn: 0.4079619	total: 13.6s	remaining: 1.25s
# 916:	learn: 0.4079242	total: 13.6s	remaining: 1.23s
# 917:	learn: 0.4079040	total: 13.6s	remaining: 1.22s
# 918:	learn: 0.4078515	total: 13.6s	remaining: 1.2s
# 919:	learn: 0.4077804	total: 13.6s	remaining: 1.19s
# 920:	learn: 0.4077658	total: 13.7s	remaining: 1.17s
# 921:	learn: 0.4077097	total: 13.7s	remaining: 1.16s
# 922:	learn: 0.4076454	total: 13.7s	remaining: 1.14s
# 923:	learn: 0.4076069	total: 13.7s	remaining: 1.13s
# 924:	learn: 0.4075539	total: 13.7s	remaining: 1.11s
# 925:	learn: 0.4074964	total: 13.7s	remaining: 1.1s
# 926:	learn: 0.4074311	total: 13.7s	remaining: 1.08s
# 927:	learn: 0.4073662	total: 13.8s	remaining: 1.07s
# 928:	learn: 0.4073268	total: 13.8s	remaining: 1.05s
# 929:	learn: 0.4072737	total: 13.8s	remaining: 1.04s
# 930:	learn: 0.4072398	total: 13.8s	remaining: 1.02s
# 931:	learn: 0.4072000	total: 13.8s	remaining: 1.01s
# 932:	learn: 0.4071102	total: 13.8s	remaining: 993ms
# 933:	learn: 0.4070462	total: 13.8s	remaining: 979ms
# 934:	learn: 0.4070356	total: 13.9s	remaining: 964ms
# 935:	learn: 0.4069367	total: 13.9s	remaining: 949ms
# 936:	learn: 0.4068536	total: 13.9s	remaining: 934ms
# 937:	learn: 0.4068242	total: 13.9s	remaining: 919ms
# 938:	learn: 0.4067629	total: 13.9s	remaining: 904ms
# 939:	learn: 0.4066782	total: 13.9s	remaining: 890ms
# 940:	learn: 0.4066405	total: 13.9s	remaining: 875ms
# 941:	learn: 0.4066214	total: 14s	remaining: 860ms
# 942:	learn: 0.4066149	total: 14s	remaining: 845ms
# 943:	learn: 0.4066059	total: 14s	remaining: 830ms
# 944:	learn: 0.4065396	total: 14s	remaining: 815ms
# 945:	learn: 0.4064695	total: 14s	remaining: 800ms
# 946:	learn: 0.4064121	total: 14s	remaining: 786ms
# 947:	learn: 0.4063515	total: 14.1s	remaining: 771ms
# 948:	learn: 0.4063033	total: 14.1s	remaining: 756ms
# 949:	learn: 0.4062587	total: 14.1s	remaining: 741ms
# 950:	learn: 0.4061952	total: 14.1s	remaining: 726ms
# 951:	learn: 0.4061482	total: 14.1s	remaining: 712ms
# 952:	learn: 0.4061284	total: 14.1s	remaining: 697ms
# 953:	learn: 0.4060596	total: 14.1s	remaining: 682ms
# 954:	learn: 0.4059957	total: 14.2s	remaining: 667ms
# 955:	learn: 0.4059299	total: 14.2s	remaining: 652ms
# 956:	learn: 0.4058862	total: 14.2s	remaining: 637ms
# 957:	learn: 0.4058279	total: 14.2s	remaining: 623ms
# 958:	learn: 0.4057678	total: 14.2s	remaining: 608ms
# 959:	learn: 0.4057071	total: 14.2s	remaining: 593ms
# 960:	learn: 0.4056669	total: 14.2s	remaining: 578ms
# 961:	learn: 0.4056286	total: 14.3s	remaining: 563ms
# 962:	learn: 0.4055743	total: 14.3s	remaining: 548ms
# 963:	learn: 0.4055072	total: 14.3s	remaining: 534ms
# 964:	learn: 0.4054443	total: 14.3s	remaining: 519ms
# 965:	learn: 0.4054241	total: 14.3s	remaining: 504ms
# 966:	learn: 0.4053983	total: 14.3s	remaining: 489ms
# 967:	learn: 0.4053341	total: 14.3s	remaining: 474ms
# 968:	learn: 0.4052767	total: 14.4s	remaining: 459ms
# 969:	learn: 0.4051966	total: 14.4s	remaining: 444ms
# 970:	learn: 0.4051319	total: 14.4s	remaining: 430ms
# 971:	learn: 0.4051015	total: 14.4s	remaining: 415ms
# 972:	learn: 0.4050976	total: 14.4s	remaining: 400ms
# 973:	learn: 0.4050457	total: 14.4s	remaining: 385ms
# 974:	learn: 0.4049951	total: 14.4s	remaining: 370ms
# 975:	learn: 0.4049520	total: 14.4s	remaining: 355ms
# 976:	learn: 0.4049100	total: 14.5s	remaining: 341ms
# 977:	learn: 0.4048503	total: 14.5s	remaining: 326ms
# 978:	learn: 0.4047985	total: 14.5s	remaining: 311ms
# 979:	learn: 0.4047432	total: 14.5s	remaining: 296ms
# 980:	learn: 0.4046691	total: 14.5s	remaining: 281ms
# 981:	learn: 0.4046153	total: 14.5s	remaining: 267ms
# 982:	learn: 0.4045619	total: 14.6s	remaining: 252ms
# 983:	learn: 0.4045163	total: 14.6s	remaining: 237ms
# 984:	learn: 0.4044787	total: 14.6s	remaining: 222ms
# 985:	learn: 0.4044205	total: 14.6s	remaining: 207ms
# 986:	learn: 0.4043752	total: 14.6s	remaining: 192ms
# 987:	learn: 0.4043312	total: 14.6s	remaining: 178ms
# 988:	learn: 0.4042651	total: 14.6s	remaining: 163ms
# 989:	learn: 0.4042520	total: 14.7s	remaining: 148ms
# 990:	learn: 0.4042184	total: 14.7s	remaining: 133ms
# 991:	learn: 0.4041516	total: 14.7s	remaining: 118ms
# 992:	learn: 0.4041013	total: 14.7s	remaining: 104ms
# 993:	learn: 0.4040324	total: 14.7s	remaining: 88.8ms
# 994:	learn: 0.4039651	total: 14.7s	remaining: 74ms
# 995:	learn: 0.4039163	total: 14.7s	remaining: 59.2ms
# 996:	learn: 0.4038780	total: 14.7s	remaining: 44.4ms
# 997:	learn: 0.4038123	total: 14.8s	remaining: 29.6ms
# 998:	learn: 0.4037662	total: 14.8s	remaining: 14.8ms
# 999:	learn: 0.4037056	total: 14.8s	remaining: 0us
#
# Elapsed Time: 0 minutes and 15.8560049533844 seconds
# CatBoost Score: {'learn': {'Logloss': 0.4037056476352299}}
# LGBM Score: defaultdict(<class 'collections.OrderedDict'>, {})

# %%
# # make predictions and average them
# lgbm_predictions = lgbm_classifier.predict_proba(X_test)
# catboost_predictions = catboost_classifier.predict_proba(X_test)

# ensemble_predictions = (lgbm_predictions[:,1] + catboost_predictions[:,1]) / 2

# print(ensemble_predictions)

# # create df for submission
# sub_df = test_df[['patient_id']]
# sub_df['DiagPeriodL90D'] = ensemble_predictions

# # save the submission
# display(sub_df)

# sub_df.to_csv('simplified_submission_ensemble_' + str(iteration4) + '.csv', index=False)
# Out:
# [0.78209194 0.78767978 0.74035985 ... 0.91637705 0.08289171 0.89772077]
# C:\Users\parth\AppData\Local\Temp\ipykernel_13088\2723398481.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df['DiagPeriodL90D'] = ensemble_predictions
#       patient_id  DiagPeriodL90D
# 0         573710        0.782092
# 1         593679        0.787680
# 2         184532        0.740360
# 3         447383        0.779405
# 4         687972        0.780880
# ...          ...             ...
# 5787      977076        0.803150
# 5788      922960        0.815225
# 5789      759690        0.916377
# 5790      911717        0.082892
# 5791      327597        0.897721
#
# [5792 rows x 2 columns]

# %%
# i think after everything, the catboost model is best. however, even this method gave me 0.803. what i just used the default params...

# %%
# # create df for submission
# sub_df = test_df[['patient_id']]
# sub_df['DiagPeriodL90D'] = lgbm_predictions[:,1]

# # save the submission
# display(sub_df)

# sub_df.to_csv('simplified_submission_lgmb_default_' + str(iteration4) + '.csv', index=False)
# Out:
# C:\Users\parth\AppData\Local\Temp\ipykernel_13088\774851475.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df['DiagPeriodL90D'] = lgbm_predictions[:,1]
#       patient_id  DiagPeriodL90D
# 0         573710        0.786436
# 1         593679        0.811058
# 2         184532        0.710468
# 3         447383        0.785878
# 4         687972        0.752877
# ...          ...             ...
# 5787      977076        0.765654
# 5788      922960        0.793714
# 5789      759690        0.923354
# 5790      911717        0.081536
# 5791      327597        0.895442
#
# [5792 rows x 2 columns]

# %%
# # create df for submission
# sub_df = test_df[['patient_id']]
# sub_df['DiagPeriodL90D'] = catboost_predictions[:,1]

# # save the submission
# display(sub_df)

# sub_df.to_csv('simplified_submission_cb_default_' + str(iteration4) + '.csv', index=False)
# Out:
# C:\Users\parth\AppData\Local\Temp\ipykernel_13088\3340256775.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df['DiagPeriodL90D'] = catboost_predictions[:,1]
#       patient_id  DiagPeriodL90D
# 0         573710        0.777748
# 1         593679        0.764302
# 2         184532        0.770252
# 3         447383        0.772932
# 4         687972        0.808883
# ...          ...             ...
# 5787      977076        0.840646
# 5788      922960        0.836737
# 5789      759690        0.909400
# 5790      911717        0.084247
# 5791      327597        0.900000
#
# [5792 rows x 2 columns]

# %%
# catboost default gave 0.802. i think catboost is the best option. let's go back and keep training CB
